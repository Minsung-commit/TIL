# %% [markdown]
# # seaborn

# %% [markdown]
# https://seaborn.pydata.org/examples/index.html#example-gallery

# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %% [markdown]
# **Distribution Plots**

# %%
tips = pd.read_csv('../Python/pandas/tips.csv')

# %%
df = tips

# %%
sns.scatterplot(data = tips, x='total_bill', y='tip', hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=df, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(data=df, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.distplot(x = 'smoker')
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-23-e1e86c0a1ad4> in <module>
# ----> 1 sns.distplot(x = 'smoker')
#
# C:\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2572
#    2573     # Make a a 1-d float array
# -> 2574     a = np.asarray(a, float)
#    2575     if a.ndim > 1:
#    2576         a = a.squeeze()
#
# C:\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'smoker'

# %%
sns.jointplot( x = 'total_bill', y = 'tip', data = tips )

# %%
sns.pairplot( tips, hue = 'sex', palette = 'coolwarm' )

# %% [markdown]
# **Categorial Plots**

# %%
import numpy as np
sns.barplot( x = 'sex', y = 'total_bill', data = tips )

# %%
sns.countplot( x = 'sex', data = tips )

# %%
sns.boxplot( x = 'day', y = 'total_bill', data = tips )

# %% [markdown]
# **Matrix Plots**

# %%
flights = sns.load_dataset('flights')
flights.head()

# %%
tc = tips.corr()
sns.heatmap(tc, annot=True, cmap = 'coolwarm')

# %%
fp = flights.pivot_table(index = 'month', columns='year', values='passengers')
fp

# %%
sns.heatmap(fp, cmap='coolwarm', linecolor='white',linewidths=1)

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# **Regression Plots**

# %%
sns.lmplot( x = 'total_bill', y = 'tip', data = tips, hue = 'sex', markers = ['o', 'v'] )

# %% [markdown]
# **Style and Color**

# %%
sns.set_style( 'white' )
sns.set_context( 'poster' )
sns.countplot( x = 'sex', data = tips )
sns.despine()

# %%
sns.lmplot( x = 'total_bill', y = 'tip', data = tips, hue = 'sex', palette = 'seismic' )

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.groupby('species').count()
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
import seaborn as sns

penguins = sns.load_dataset("penguins")

# %%
penguins.groupby('species').count()
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue='sex', data=penguins)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %% [markdown]
# palette : refer to 'matplotlib colormap'
#
# https://matplotlib.org/examples/color/colormaps_reference.html
