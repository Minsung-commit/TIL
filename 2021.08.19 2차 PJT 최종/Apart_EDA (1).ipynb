# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 사용 데이터셋
# - 서울 집값(20,21)
# - kaggle 한국 집값
# - 전국 지역 코드 데이터

# %%
df_20 = pd.read_csv('./Apart_2020.csv', encoding = 'cp949')
df_21 = pd.read_csv('./Apart_2021.csv', encoding = 'cp949')

# %%
df_20.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    54.98  202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   22
#
#   거래금액(만원)  층  건축년도      도로명  해제사유발생일
# 0  149,500  4  1988  언주로 103      NaN
# 1  144,000  4  1987    언주로 3      NaN
# 2  162,750  4  1987    언주로 3      NaN
# 3  160,000  5  1987    언주로 3      NaN
# 4  150,000  2  1987    언주로 3      NaN

# %%
df_21.head()
# Out:
#              시군구     번지      본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2   655.0  2.0  개포2차현대아파트(220)    77.75  202104   15
# 1  서울특별시 강남구 개포동  658-1   658.0  1.0  개포6차우성아파트1동~8동    79.97  202105   15
# 2  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    59.92  202105   22
# 3  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    49.92  202105   22
# 4  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    59.92  202106   13
#
#   거래금액(만원)   층  건축년도      도로명     해제사유발생일
# 0  174,000   9  1988  언주로 103         NaN
# 1  195,000   5  1987    언주로 3         NaN
# 2  198,500  18  2020  개포로 264  20210526.0
# 3  180,000   7  2020  개포로 264  20210526.0
# 4  210,000   5  2020  개포로 264         NaN

# %%
df = pd.concat([df_20,df_21])

# %%
df.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    54.98  202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   22
#
#   거래금액(만원)  층  건축년도      도로명  해제사유발생일
# 0  149,500  4  1988  언주로 103      NaN
# 1  144,000  4  1987    언주로 3      NaN
# 2  162,750  4  1987    언주로 3      NaN
# 3  160,000  5  1987    언주로 3      NaN
# 4  150,000  2  1987    언주로 3      NaN

# %%
df.tail()
# Out:
#                  시군구      번지     본번    부번      단지명  전용면적(㎡)    계약년월  계약일  \
# 29918  서울특별시 중랑구 중화동     450  450.0   0.0      한신2    59.76  202104   10
# 29919  서울특별시 중랑구 중화동     450  450.0   0.0      한신2    59.76  202104   16
# 29920  서울특별시 중랑구 중화동  274-51  274.0  51.0  한영(101)    57.66  202102   27
# 29921  서울특별시 중랑구 중화동  274-75  274.0  75.0  한영(102)    72.22  202105    4
# 29922  서울특별시 중랑구 중화동  274-76  274.0  76.0  한영(103)    58.46  202107    1
#
#       거래금액(만원)   층  건축년도         도로명  해제사유발생일
# 29918   66,000   6  1998     동일로 752      NaN
# 29919   68,000  13  1998     동일로 752      NaN
# 29920   30,500   5  2003  동일로144길 74      NaN
# 29921   49,500   4  2003  동일로144길 74      NaN
# 29922   30,000   2  2003  동일로144길 74      NaN

# %%
apart = pd.read_csv('./Apart_Deal.csv')
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
apart.head()
# Out:
#     지역코드  법정동             거래일       아파트     지번      전용면적   층  건축년도   거래금액
# 0  31110  학성동  5/30/2020 0:00    남운학성타운    379  135.5800   8  1991  26700
# 1  31110  남외동   1/3/2020 0:00  남외푸르지오1차  506-1  101.6000   2  2006  35500
# 2  31110  남외동   1/3/2020 0:00     에일린의뜰    500   84.9920  11  2007  36500
# 3  31110  남외동   1/3/2020 0:00  남외푸르지오1차  506-1  118.7060   8  2006  43000
# 4  31110  남외동   1/4/2020 0:00  남외푸르지오2차  501-1   84.9636   7  2007  38700

# %%
total = pd.read_csv('./dong_total.txt', sep='\t')

# %%
total.head()
# Out:
#         법정동코드           법정동명 폐지여부
# 0  1100000000          서울특별시   존재
# 1  1111000000      서울특별시 종로구   존재
# 2  1111010100  서울특별시 종로구 청운동   존재
# 3  1111010200  서울특별시 종로구 신교동   존재
# 4  1111010300  서울특별시 종로구 궁정동   존재

# %% [markdown]
# ## seoul_Apart EDA

# %%
df.columns = ['location', 'bun', 'bun_1', 'bun_2', 'name', 'square', 'date_ym', 'day', 'cost', 'floor', 'blit_year', 'road_name', 'de']

# %%
df.head()
# Out:
#         location    bun  bun_1  bun_2            name  square  date_ym  day  \
# 0  서울특별시 강남구 개포동  655-2  655.0    2.0  개포2차현대아파트(220)   77.75   202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   54.98   202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   22
#
#       cost  floor  blit_year road_name  de
# 0  149,500      4       1988   언주로 103 NaN
# 1  144,000      4       1987     언주로 3 NaN
# 2  162,750      4       1987     언주로 3 NaN
# 3  160,000      5       1987     언주로 3 NaN
# 4  150,000      2       1987     언주로 3 NaN

# %%
df.name.value_counts()
# Out:
# 현대              1069
# 두산               863
# 한신               856
# 벽산               683
# 삼성래미안            648
#                 ...
# 경성빌라               1
# 경성아파트              1
# 계영주택(738-27)       1
# 낙원빌라               1
# 광남캐스빌B             1
# Name: name, Length: 6205, dtype: int64

# %%
seoul = df.drop(['bun', 'bun_1', 'bun_2', 'day', 'road_name', 'de'],axis=1)

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987

# %%
len(seoul.location.unique())
# Out:
# 329

# %%
# 주소 분할 군, 동
seoul['gu'] = seoul.location.str.split(' ').str[1]
seoul['dong'] = seoul.location.str.split(' ').str[2]

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong
# 0  강남구  개포동
# 1  강남구  개포동
# 2  강남구  개포동
# 3  강남구  개포동
# 4  강남구  개포동

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   location   114149 non-null  object
#  1   name       114149 non-null  object
#  2   square     114149 non-null  float64
#  3   date_ym    114149 non-null  int64
#  4   cost       114149 non-null  object
#  5   floor      114149 non-null  int64
#  6   blit_year  114149 non-null  int64
#  7   gu         114149 non-null  object
#  8   dong       114149 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 8.7+ MB

# %%
seoul.isnull().sum()
# Out:
# location     0
# name         0
# square       0
# date_ym      0
# cost         0
# floor        0
# blit_year    0
# gu           0
# dong         0
# dtype: int64

# %%
# 구별 빈도수
count_gu = seoul.gu.value_counts()

# %%
count_gu = pd.DataFrame(count_gu).reset_index()

# %%
count_gu.plot.bar(x='index', y='gu', rot=0)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
count_gu
# Out:
#    index     gu
# 0    노원구  12066
# 1    강서구   7796
# 2    구로구   6940
# 3    송파구   6059
# 4    도봉구   5995
# 5    성북구   5966
# 6    강동구   5637
# 7    강남구   5465
# 8    서초구   4859
# 9    양천구   4851
# 10  영등포구   4676
# 11   은평구   4537
# 12  동대문구   4417
# 13   성동구   4029
# 14   중랑구   4009
# 15   동작구   3936
# 16   마포구   3839
# 17  서대문구   3697
# 18   관악구   3668
# 19   강북구   2848
# 20   금천구   2370
# 21   용산구   2158
# 22   광진구   1783
# 23    중구   1468
# 24   종로구   1080

# %%
# 판매 년도, 연식 계산

seoul['sale_y'] = seoul.date_ym.astype(str).str[:4].astype(int)

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   location   114149 non-null  object
#  1   name       114149 non-null  object
#  2   square     114149 non-null  float64
#  3   date_ym    114149 non-null  int64
#  4   cost       114149 non-null  object
#  5   floor      114149 non-null  int64
#  6   blit_year  114149 non-null  int64
#  7   gu         114149 non-null  object
#  8   dong       114149 non-null  object
#  9   sale_y     114149 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 9.6+ MB

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong  sale_y
# 0  강남구  개포동    2020
# 1  강남구  개포동    2020
# 2  강남구  개포동    2020
# 3  강남구  개포동    2020
# 4  강남구  개포동    2020

# %%
seoul['used_y'] = seoul['sale_y']-seoul['blit_year']

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong  sale_y  used_y
# 0  강남구  개포동    2020      32
# 1  강남구  개포동    2020      33
# 2  강남구  개포동    2020      33
# 3  강남구  개포동    2020      33
# 4  강남구  개포동    2020      33

# %%
# 가격 숫자형으로 변환 ','삭제
seoul["cost"] = df["cost"].str.replace(pat=r'[^\w]', repl=r'', regex=True).astype(int)

# %%
seoul.head()
# Out:
#         location            name  square  date_ym    cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150000      2       1987
#
#     gu dong  sale_y  used_y
# 0  강남구  개포동    2020      32
# 1  강남구  개포동    2020      33
# 2  강남구  개포동    2020      33
# 3  강남구  개포동    2020      33
# 4  강남구  개포동    2020      33

# %%
top10 = ['자이', '푸르지오', '더샵', '롯데캐슬', '이편한|e편한|e-편한',
         '힐스테이트', '아이파크', '래미안', 'sk|SK|에스케이', '데시앙']
seoul['top10']=0
for brand in top10:
    seoul.loc[seoul['name'].str.contains(brand),'top10'] = 1

# %%
# 평단가 계산
seoul['per_cost_man'] = seoul['cost'] / seoul['square']

# %%
seoul.head()
# Out:
#         location            name  square  date_ym    cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150000      2       1987
#
#     gu dong  sale_y  used_y  top10  per_cost_man
# 0  강남구  개포동    2020      32      0   1922.829582
# 1  강남구  개포동    2020      33      0   2619.134231
# 2  강남구  개포동    2020      33      0   2035.138177
# 3  강남구  개포동    2020      33      0   2000.750281
# 4  강남구  개포동    2020      33      0   1875.703389

# %%
# 테이블 정리
seoul = seoul[['location', 'gu', 'dong', 'date_ym', 'blit_year', 'sale_y', 'used_y', 'square', 'per_cost_man', 'name', 'floor','top10', 'cost']]

# %%
seoul.top10.value_counts()
# Out:
# 0    93597
# 1    20552
# Name: top10, dtype: int64

# %%
seoul.head()
# Out:
#         location   gu dong  date_ym  blit_year  sale_y  used_y  square  \
# 0  서울특별시 강남구 개포동  강남구  개포동   202006       1988    2020      32   77.75
# 1  서울특별시 강남구 개포동  강남구  개포동   202002       1987    2020      33   54.98
# 2  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
# 3  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
# 4  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
#
#    per_cost_man            name  floor  top10    cost
# 0   1922.829582  개포2차현대아파트(220)      4      0  149500
# 1   2619.134231  개포6차우성아파트1동~8동      4      0  144000
# 2   2035.138177  개포6차우성아파트1동~8동      4      0  162750
# 3   2000.750281  개포6차우성아파트1동~8동      5      0  160000
# 4   1875.703389  개포6차우성아파트1동~8동      2      0  150000

# %%
seoul_1 = seoul.drop(['location', 'date_ym', 'blit_year', 'sale_y'], axis=1)

# %%
seoul_1.head()
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor  top10  \
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4      0
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4      0
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4      0
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5      0
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2      0
#
#      cost
# 0  149500
# 1  144000
# 2  162750
# 3  160000
# 4  150000

# %%
seoul_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gu            114149 non-null  object
#  1   dong          114149 non-null  object
#  2   used_y        114149 non-null  int64
#  3   square        114149 non-null  float64
#  4   per_cost_man  114149 non-null  float64
#  5   name          114149 non-null  object
#  6   floor         114149 non-null  int64
#  7   top10         114149 non-null  int64
#  8   cost          114149 non-null  int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.7+ MB

# %%
# 아파트 명 단어 추출
seoul_1['token'] = seoul_1["name"].str.replace(pat=r'[아파트]|[^\w]|[0-9]|[동]', repl=r'', regex=True).str.split('차').str[-1]

# %%
seoul_1.head()
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor  top10  \
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4      0
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4      0
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4      0
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5      0
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2      0
#
#      cost token
# 0  149500    현대
# 1  144000    우성
# 2  162750    우성
# 3  160000    우성
# 4  150000    우성

# %%
seoul_1['YN_r'] = 0
seoul_1['temp'] = seoul_1['dong'].str.replace(pat=r'[동]', repl=r'', regex=True)

# %%
dong_list = list(seoul_1['temp'].unique())

# %%
for i in dong_list:
     seoul_1.loc[seoul_1['name'].str.contains(i), 'YN_r'] = 1

# %%
seoul_1['token'].value_counts()[:11]
# Out:
#           6551
# 상계주공고층    2392
# 현대        2315
# 주공        1618
# 신         1492
# 한신        1242
# 우성        1212
# 목신시가지     1057
# 두산         955
# 벽산         836
# 삼성래미안      766
# Name: token, dtype: int64

# %%
seoul_1['YN_top10'] = 0

# %%
top_list = ['상계주공고층', '현대', '주공', '신', '한신', '우성', '목신시가지', '두산', '벽산', '삼성래미안']

# %%
for i in top_list:
     seoul_1.loc[seoul_1['name'].str.contains(i), 'YN_top10'] = 1

# %%
seoul_1.head(5)
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor  top10  \
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4      0
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4      0
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4      0
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5      0
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2      0
#
#      cost token  YN_r temp  YN_top10
# 0  149500    현대     1   개포         1
# 1  144000    우성     1   개포         1
# 2  162750    우성     1   개포         1
# 3  160000    우성     1   개포         1
# 4  150000    우성     1   개포         1

# %%
seoul_1.groupby('dong')['cost'].agg('mean').sort_values(ascending=False)
# Out:
# dong
# 신문로2가     321500.000000
# 압구정동      317315.647482
# 반포동       278913.077935
# 용산동5가     254241.228070
# 서빙고동      227587.500000
#               ...
# 충신동        15637.500000
# 영등포동4가     14300.000000
# 원남동        13830.695652
# 영등포동3가     11553.846154
# 장충동2가      10441.666667
# Name: cost, Length: 327, dtype: float64

# %%
seoul_1.groupby('dong')['cost'].agg('median').sort_values(ascending=False)
# Out:
# dong
# 신문로2가     340500.0
# 장충동1가     304000.0
# 압구정동      281500.0
# 반포동       266000.0
# 서빙고동      243000.0
#             ...
# 영등포동2가     13600.0
# 영등포동1가     13500.0
# 원남동        13373.0
# 영등포동3가     11700.0
# 장충동2가      10725.0
# Name: cost, Length: 327, dtype: float64

# %%
seoul_1
# Out:
#         gu dong  used_y  square  per_cost_man            name  floor  top10  \
# 0      강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4      0
# 1      강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4      0
# 2      강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4      0
# 3      강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5      0
# 4      강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2      0
# ...    ...  ...     ...     ...           ...             ...    ...    ...
# 29918  중랑구  중화동      23   59.76   1104.417671             한신2      6      0
# 29919  중랑구  중화동      23   59.76   1137.884873             한신2     13      0
# 29920  중랑구  중화동      18   57.66    528.962886         한영(101)      5      0
# 29921  중랑구  중화동      18   72.22    685.405705         한영(102)      4      0
# 29922  중랑구  중화동      18   58.46    513.171399         한영(103)      2      0
#
#          cost token  YN_r temp  YN_top10
# ...

# %%
# seoul_1.to_csv('seoul_1.csv')

# %%
seoul_2 = seoul_1.drop(['name'], axis=1)

# %%
seoul_2 = seoul_2[['gu', 'dong', 'used_y', 'square', 'per_cost_man', 'floor','top10', 'YN_r', 'YN_top10', 'token', 'temp', 'cost']]

# %%
seoul_2.top10.value_counts()
# Out:
# 0    93597
# 1    20552
# Name: top10, dtype: int64

# %%
seoul_2.corr()
# Out:
#                 used_y    square  per_cost_man     floor     top10      YN_r  \
# used_y        1.000000  0.007994     -0.058961 -0.168312 -0.414409 -0.044762
# square        0.007994  1.000000      0.028883  0.111879  0.147409  0.003526
# per_cost_man -0.058961  0.028883      1.000000  0.168899  0.221279  0.144773
# floor        -0.168312  0.111879      0.168899  1.000000  0.136854 -0.005599
# top10        -0.414409  0.147409      0.221279  0.136854  1.000000  0.176992
# YN_r         -0.044762  0.003526      0.144773 -0.005599  0.176992  1.000000
# YN_top10      0.333772 -0.039698     -0.021931 -0.024398 -0.162885  0.065888
# cost         -0.022887  0.621963      0.739961  0.194177  0.231201  0.091845
#
#               YN_top10      cost
# used_y        0.333772 -0.022887
# square       -0.039698  0.621963
# per_cost_man -0.021931  0.739961
# floor        -0.024398  0.194177
# top10        -0.162885  0.231201
# YN_r          0.065888  0.091845
# YN_top10      1.000000 -0.042138
# ...

# %%
seoul_2[seoul_2['used_y'] < 0]
# Out:
#          gu dong  used_y   square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 6177    강동구  상일동      -1  84.9712   1871.222249     18      1     1         0
# 43638  동대문구  휘경동      -1  59.7700   1455.579722     17      0     1         0
# 69821   양천구  신정동      -1  59.9800   2250.750250     26      1     1         0
# 73097  영등포구  신길동      -1  59.9800   1543.847949     11      1     1         1
# 73098  영등포구  신길동      -1  59.9800   1825.608536     26      1     1         1
# 73099  영등포구  신길동      -1  59.9800   1747.249083      3      1     1         1
#
#             token temp    cost
# 6177         고덕자이   상일  159000
# 43638  휘경해모로프레스티지   휘경   87000
# 69821     래미안목델리체   신정  135000
# 73097      신길센럴자이   신길   92600
# 73098      신길센럴자이   신길  109500
# 73099      신길센럴자이   신길  104800

# %%
seoul_2[seoul_2['floor'] < 0]
# Out:
#          gu  dong  used_y    square  per_cost_man  floor  top10  YN_r  \
# 2276    강남구   신사동      13   73.2200    532.641355     -1      0     0
# 15747   강서구   화곡동      14   63.2100    205.663661     -1      0     1
# 24996   구로구   천왕동       6   84.9500    752.207181     -1      0     1
# 25009   구로구   천왕동       6   84.7800    798.537391     -2      0     1
# 26356   금천구   시흥동      29   57.6900    202.808112     -1      0     0
# 37944   도봉구   쌍문동      20   42.0000    154.761905     -1      0     0
# 43614  동대문구   휘경동      48   42.2800    473.036897     -1      0     1
# 45291   동작구  상도1동      14   78.2200    434.671440     -1      0     1
# 45909   동작구   상도동      17   84.1800    376.574008     -1      0     0
# 46451   동작구   흑석동       1   84.9108   2002.101028     -3      0     0
# 46453   동작구   흑석동       1   84.9108   2002.101028     -3      0     0
# 47077   마포구   대흥동      14   75.0600    826.005862     -1      0     0
# ...

# %%
# 연식= -1(청약인 경우), floor < 0 인경우 (지하) 처리
# 연식은 0으로 초기화
# floor는 지하층수를 자연수로 표현하기 위해서 최솟값 -3을 확인, +3을 해준다

seoul_2[seoul_2['used_y'] < 0] = 0
seoul_2['floor'] += 3

# %%
seoul_2.describe()
# Out:
#               used_y         square   per_cost_man          floor  \
# count  114149.000000  114149.000000  114149.000000  114149.000000
# mean       19.540504      75.495059    1168.314368      12.029821
# std         9.876961      30.601143     573.990160       6.125836
# min         0.000000       0.000000       0.000000       0.000000
# 25%        13.000000      59.400000     775.228336       7.000000
# 50%        19.000000      76.510000    1032.326569      11.000000
# 75%        26.000000      84.960000    1408.367708      16.000000
# max        60.000000     317.360000    5471.097755      70.000000
#
#                top10           YN_r       YN_top10          cost
# count  114149.000000  114149.000000  114149.000000  1.141490e+05
# mean        0.180002       0.374633       0.294808  8.871414e+04
# std         0.384190       0.484030       0.455958  6.168755e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# ...

# %%
# seoul_2.to_csv('seoul_2.csv')

# %%
seoul_2.head()
# Out:
#     gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10 token  \
# 0  강남구  개포동      32   77.75   1922.829582      7      0     1         1    현대
# 1  강남구  개포동      33   54.98   2619.134231      7      0     1         1    우성
# 2  강남구  개포동      33   79.97   2035.138177      7      0     1         1    우성
# 3  강남구  개포동      33   79.97   2000.750281      8      0     1         1    우성
# 4  강남구  개포동      33   79.97   1875.703389      5      0     1         1    우성
#
#   temp    cost
# 0   개포  149500
# 1   개포  144000
# 2   개포  162750
# 3   개포  160000
# 4   개포  150000

# %%
seoul_3 = seoul_2.drop(['token','temp'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
seoul_3.gu.unique()
# Out:
# array(['강남구', '강동구', 0, '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
# gu값이 0인 행 삭제
seoul_3 = seoul_3.drop(seoul_3[seoul_3['gu']==0].index)

# %%
# 라벨링
le.fit(seoul_3.gu)
# Out:
# LabelEncoder()

# %%
le.transform(seoul_3.gu)
# Out:
# array([ 0,  0,  0, ..., 24, 24, 24])

# %%
seoul_3['gu_l'] = le.transform(seoul_3.gu)

# %%
seoul_3.gu_l.value_counts()
# Out:
# 8     12066
# 3      7796
# 6      6940
# 17     6059
# 9      5995
# 16     5966
# 1      5636
# 0      5465
# 14     4859
# 18     4850
# 19     4673
# 21     4537
# 10     4416
# 15     4029
# 24     4009
# 11     3936
# 12     3839
# 13     3697
# 4      3667
# 2      2848
# 7      2370
# 20     2158
# 5      1783
# 23     1468
# 22     1080
# Name: gu_l, dtype: int64

# %%
seoul_3.gu.value_counts()
# Out:
# 노원구     12066
# 강서구      7796
# 구로구      6940
# 송파구      6059
# 도봉구      5995
# 성북구      5966
# 강동구      5636
# 강남구      5465
# 서초구      4859
# 양천구      4850
# 영등포구     4673
# 은평구      4537
# 동대문구     4416
# 성동구      4029
# 중랑구      4009
# 동작구      3936
# 마포구      3839
# 서대문구     3697
# 관악구      3667
# 강북구      2848
# 금천구      2370
# 용산구      2158
# 광진구      1783
# 중구       1468
# 종로구      1080
# Name: gu, dtype: int64

# %%
# 동 라벨링
le_1 = LabelEncoder()
le_1.fit(seoul_3.dong)
seoul_3['dong_l']=le_1.transform(seoul_3.dong)

# %%
seoul_3.head()
# Out:
#     gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 0  강남구  개포동      32   77.75   1922.829582      7      0     1         1
# 1  강남구  개포동      33   54.98   2619.134231      7      0     1         1
# 2  강남구  개포동      33   79.97   2035.138177      7      0     1         1
# 3  강남구  개포동      33   79.97   2000.750281      8      0     1         1
# 4  강남구  개포동      33   79.97   1875.703389      5      0     1         1
#
#      cost  gu_l  dong_l
# 0  149500     0       8
# 1  144000     0       8
# 2  162750     0       8
# 3  160000     0       8
# 4  150000     0       8

# %%
# 지하철 역 개수 추가

df_s = pd.read_excel('./seoul_subway.xls')

# %%
df_s.head()
# Out:
#   서울교통공사 역 주소 현황(행정동 기준) Unnamed: 1         Unnamed: 2          Unnamed: 3  \
# 0                     번호        역 명          행정동(법정동)명                역 주소
# 1                      1     서울(1)역         회현동(봉래동2가)    서울시 중구 봉래동2가 122
# 2                      2     시청(1)역          명동(태평로1가)     서울시 중구 태평로1가 31
# 3                      3     종각(1)역  종로1.2.3.4가동(종로1가)     서울시 종로구 종로1가 44
# 4                      4   종로3가(1)역  종로1.2.3.4가동(종로3가)  서울시 종로구 종로3가 61-68
#
#   Unnamed: 4
# 0       우편번호
# 1      04509
# 2      04519
# 3      03161
# 4      03139

# %%
df_s1 = df_s[['Unnamed: 1','Unnamed: 2' ]]

# %%
df_s1.columns = ['st', 'dong']

# %%
df_s1.head()
# Out:
#          st               dong
# 0       역 명          행정동(법정동)명
# 1    서울(1)역         회현동(봉래동2가)
# 2    시청(1)역          명동(태평로1가)
# 3    종각(1)역  종로1.2.3.4가동(종로1가)
# 4  종로3가(1)역  종로1.2.3.4가동(종로3가)

# %%
# 호선이 다르면 다른 역으로 확인됨
df_s1['st_r'] =  df_s1['st'].str.replace(pat=r'[^\w]', repl=r'', regex=True).str[:-2]
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_s1.head()
# Out:
#          st               dong  st_r
# 0       역 명          행정동(법정동)명
# 1    서울(1)역         회현동(봉래동2가)    서울
# 2    시청(1)역          명동(태평로1가)    시청
# 3    종각(1)역  종로1.2.3.4가동(종로1가)    종각
# 4  종로3가(1)역  종로1.2.3.4가동(종로3가)  종로3가

# %%
a = list(df_s1.dong.str.find('(').astype(int))
b = list(df_s1.dong.str.find(')').astype(int))

# %%
 df_s1.dong.loc[1]
# Out:
# '회현동(봉래동2가)'

# %%
for i in range(len(a)):
    df_s1.dong.loc[i] = df_s1.dong.loc[i][a[i]+1:-1]
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df_s1
# Out:
#              st   dong    st_r
# 0           역 명   법정동)
# 1        서울(1)역  봉래동2가      서울
# 2        시청(1)역  태평로1가      시청
# 3        종각(1)역   종로1가      종각
# 4      종로3가(1)역   종로3가    종로3가
# ..          ...    ...     ...
# 276  남한산성입구(8)역    단대동  남한산성입구
# 277   단대오거리(8)역    신흥동   단대오거리
# 278      신흥(8)역    신흥동      신흥
# 279      수진(8)역    수진동      수진
# 280      모란(8)역    수진동      모란
#
# [281 rows x 3 columns]

# %%
df_s1.drop([0], inplace=True)
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/frame.py:4908: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_s1.head()
# Out:
#          st   dong  st_r
# 1    서울(1)역  봉래동2가    서울
# 2    시청(1)역  태평로1가    시청
# 3    종각(1)역   종로1가    종각
# 4  종로3가(1)역   종로3가  종로3가
# 5  종로5가(1)역   종로5가  종로5가

# %%
df_s1_r = df_s1.drop(['st'], axis=1)

# %%
df_s1_r[df_s1_r['dong'] == '신당동']
# Out:
#     dong  st_r
# 16   신당동    신당
# 75   신당동    약수
# 148  신당동    청구
# 196  신당동  버티고개
# 197  신당동    약수
# 198  신당동    청구
# 199  신당동    신당

# %%
df_s1_r1 = df_s1_r.drop_duplicates()

# %%
df_s1_r1[df_s1_r1.dong == '신당동']
# Out:
#     dong  st_r
# 16   신당동    신당
# 75   신당동    약수
# 148  신당동    청구
# 196  신당동  버티고개

# %%
df_s2 = pd.DataFrame(df_s1_r1.dong.value_counts())

# %%
df_s2
# Out:
#        dong
# 방배동       5
# 상계동       5
# 가락동       5
# 신당동       4
# 사당동       3
# ...     ...
# 길음동       1
# 수유동       1
# 수서동       1
# 일원동       1
# 용산동5가     1
#
# [174 rows x 1 columns]

# %%
list(df_s2.index).index('방배동')
# Out:
# 0

# %%
df_s2.dong[0]
# Out:
# 5

# %%
seoul_3['s_c'] = 0

# %%
seoul_3.head()
# Out:
#     gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 0  강남구  개포동      32   77.75   1922.829582      7      0     1         1
# 1  강남구  개포동      33   54.98   2619.134231      7      0     1         1
# 2  강남구  개포동      33   79.97   2035.138177      7      0     1         1
# 3  강남구  개포동      33   79.97   2000.750281      8      0     1         1
# 4  강남구  개포동      33   79.97   1875.703389      5      0     1         1
#
#      cost  gu_l  dong_l  s_c
# 0  149500     0       8    0
# 1  144000     0       8    0
# 2  162750     0       8    0
# 3  160000     0       8    0
# 4  150000     0       8    0

# %%
for i in list(df_s2.index):
     seoul_3.loc[seoul_3['dong'].str.contains(i), 's_c'] = df_s2.dong[list(df_s2.index).index(i)]

# %%
seoul_3.head()
# Out:
#     gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 0  강남구  개포동      32   77.75   1922.829582      7      0     1         1
# 1  강남구  개포동      33   54.98   2619.134231      7      0     1         1
# 2  강남구  개포동      33   79.97   2035.138177      7      0     1         1
# 3  강남구  개포동      33   79.97   2000.750281      8      0     1         1
# 4  강남구  개포동      33   79.97   1875.703389      5      0     1         1
#
#      cost  gu_l  dong_l  s_c
# 0  149500     0       8    1
# 1  144000     0       8    1
# 2  162750     0       8    1
# 3  160000     0       8    1
# 4  150000     0       8    1

# %%
seoul_3.tail()
# Out:
#         gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 29918  중랑구  중화동      23   59.76   1104.417671      9      0     0         1
# 29919  중랑구  중화동      23   59.76   1137.884873     16      0     0         1
# 29920  중랑구  중화동      18   57.66    528.962886      8      0     0         0
# 29921  중랑구  중화동      18   72.22    685.405705      7      0     0         0
# 29922  중랑구  중화동      18   58.46    513.171399      5      0     0         0
#
#         cost  gu_l  dong_l  s_c
# 29918  66000    24     266    1
# 29919  68000    24     266    1
# 29920  30500    24     266    1
# 29921  49500    24     266    1
# 29922  30000    24     266    1

# %%
seoul_3[seoul_3['dong'] == '신당동']
# Out:
#        gu dong  used_y   square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 80386  중구  신당동      19   56.090    240.684614      2      0     0         0
# 80387  중구  신당동      17   74.960    707.043757      7      0     0         0
# 80388  중구  신당동      17   61.490    886.322979      7      0     0         0
# 80389  중구  신당동      18   58.670    392.023181      8      0     0         0
# 80390  중구  신당동      15  143.049    699.061161     15      0     1         0
# ...    ..  ...     ...      ...           ...    ...    ...   ...       ...
# 28605  중구  신당동      28  122.275    924.146391     17      0     0         1
# 28606  중구  신당동      28   83.970   1119.447422      7      0     0         1
# 28607  중구  신당동      28   79.110   1175.578309     12      0     0         1
# 28608  중구  신당동      28   66.600   1351.351351     16      0     0         1
# 28609  중구  신당동      28   66.600   1328.828829     12      0     0         1
#
#          cost  gu_l  dong_l  s_c
# ...

# %%
seoul_3.to_csv('seoul_3.csv', index=False)

# %%
seoul_4 = seoul_3.drop(['gu','dong'], axis=1)
seoul_4 = seoul_4[['gu_l','dong_l','s_c','used_y','square','per_cost_man','floor','top10', 'YN_r','YN_top10','cost']]

# %%
seoul_4
# Out:
#        gu_l  dong_l  s_c  used_y  square  per_cost_man  floor  top10  YN_r  \
# 0         0       8    1      32   77.75   1922.829582      7      0     1
# 1         0       8    1      33   54.98   2619.134231      7      0     1
# 2         0       8    1      33   79.97   2035.138177      7      0     1
# 3         0       8    1      33   79.97   2000.750281      8      0     1
# 4         0       8    1      33   79.97   1875.703389      5      0     1
# ...     ...     ...  ...     ...     ...           ...    ...    ...   ...
# 29918    24     266    1      23   59.76   1104.417671      9      0     0
# 29919    24     266    1      23   59.76   1137.884873     16      0     0
# 29920    24     266    1      18   57.66    528.962886      8      0     0
# 29921    24     266    1      18   72.22    685.405705      7      0     0
# 29922    24     266    1      18   58.46    513.171399      5      0     0
#
#        YN_top10    cost
# 0             1  149500
# ...

# %%
seoul_4.to_csv('seoul_4.csv', index=False)

# %%
seoul_3_1 = pd.read_csv('./seoul_3_1.csv')

# %%
seoul_3_1.head(1)
# Out:
#    Unnamed: 0   gu dong  used_y  square  per_cost_man  floor  top10  YN_r  \
# 0           0  강남구  개포동      32   77.75   1922.829582      7      0     1
#
#    YN_top10    cost  gu_l  dong_l  s_c  Hospital  Price per squar
# 0         1  149500     0       8    1       0.0      2122.127392

# %%
seoul_3_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114142 entries, 0 to 114141
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       114142 non-null  int64
#  1   gu               114142 non-null  object
#  2   dong             114142 non-null  object
#  3   used_y           114142 non-null  int64
#  4   square           114142 non-null  float64
#  5   per_cost_man     114142 non-null  float64
#  6   floor            114142 non-null  int64
#  7   top10            114142 non-null  int64
#  8   YN_r             114142 non-null  int64
#  9   YN_top10         114142 non-null  int64
#  10  cost             114142 non-null  int64
#  11  gu_l             114142 non-null  int64
#  12  dong_l           114142 non-null  int64
#  13  s_c              114142 non-null  int64
#  14  Hospital         114142 non-null  float64
#  15  Price per squar  114142 non-null  float64
# ...

# %%
seoul_5 = seoul_3_1.drop('Unnamed: 0', axis=1)

# %%
seoul_5.head()
# Out:
#     gu dong  used_y  square  per_cost_man  floor  top10  YN_r  YN_top10  \
# 0  강남구  개포동      32   77.75   1922.829582      7      0     1         1
# 1  강남구  개포동      33   54.98   2619.134231      7      0     1         1
# 2  강남구  개포동      33   79.97   2035.138177      7      0     1         1
# 3  강남구  개포동      33   79.97   2000.750281      8      0     1         1
# 4  강남구  개포동      33   79.97   1875.703389      5      0     1         1
#
#      cost  gu_l  dong_l  s_c  Hospital  Price per squar
# 0  149500     0       8    1       0.0      2122.127392
# 1  144000     0       8    1       0.0      2122.127392
# 2  162750     0       8    1       0.0      2122.127392
# 3  160000     0       8    1       0.0      2122.127392
# 4  150000     0       8    1       0.0      2122.127392

# %%
seoul_5.drop(['gu','dong'], axis=1, inplace=True)

# %%
seoul_5.columns
# Out:
# Index(['used_y', 'square', 'per_cost_man', 'floor', 'top10', 'YN_r',
#        'YN_top10', 'cost', 'gu_l', 'dong_l', 's_c', 'Hospital',
#        'Price per squar'],
#       dtype='object')

# %%
seoul_5 = seoul_5[['gu_l', 'dong_l', 'used_y', 'square', 'per_cost_man', 'Price per squar', 'floor', 'top10', 'YN_r',
       'YN_top10',  's_c', 'Hospital', 'cost']]

# %%
seoul_5
# Out:
#         gu_l  dong_l  used_y  square  per_cost_man  Price per squar  floor  \
# 0          0       8      32   77.75   1922.829582      2122.127392      7
# 1          0       8      33   54.98   2619.134231      2122.127392      7
# 2          0       8      33   79.97   2035.138177      2122.127392      7
# 3          0       8      33   79.97   2000.750281      2122.127392      8
# 4          0       8      33   79.97   1875.703389      2122.127392      5
# ...      ...     ...     ...     ...           ...              ...    ...
# 114137    24     266      23   59.76   1104.417671       809.799405      9
# 114138    24     266      23   59.76   1137.884873       809.799405     16
# 114139    24     266      18   57.66    528.962886       809.799405      8
# 114140    24     266      18   72.22    685.405705       809.799405      7
# 114141    24     266      18   58.46    513.171399       809.799405      5
#
#         top10  YN_r  YN_top10  s_c  Hospital    cost
# ...

# %%
seoul_5.to_csv('seoul_5.csv', index=False)
