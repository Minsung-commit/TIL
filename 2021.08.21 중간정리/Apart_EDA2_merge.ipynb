# %% [markdown]
# <a href="https://colab.research.google.com/github/Minsung-commit/TIL/blob/master/Apart_EDA2_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 사용 데이터셋
# - 서울 집값(20,21)
# - kaggle 한국 집값
# - 전국 지역 코드 데이터

# %%
df_20 = pd.read_csv('./Apart_2020.csv', encoding = 'cp949')
df_21 = pd.read_csv('./Apart_2021.csv', encoding = 'cp949')

# %%
df_20.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    54.98  202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   22
#
#   거래금액(만원)  층  건축년도      도로명  해제사유발생일
# 0  149,500  4  1988  언주로 103      NaN
# 1  144,000  4  1987    언주로 3      NaN
# 2  162,750  4  1987    언주로 3      NaN
# 3  160,000  5  1987    언주로 3      NaN
# 4  150,000  2  1987    언주로 3      NaN

# %%
df_21.head()
# Out:
#              시군구     번지      본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2   655.0  2.0  개포2차현대아파트(220)    77.75  202104   15
# 1  서울특별시 강남구 개포동  658-1   658.0  1.0  개포6차우성아파트1동~8동    79.97  202105   15
# 2  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    59.92  202105   22
# 3  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    49.92  202105   22
# 4  서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트    59.92  202106   13
#
#   거래금액(만원)   층  건축년도      도로명     해제사유발생일
# 0  174,000   9  1988  언주로 103         NaN
# 1  195,000   5  1987    언주로 3         NaN
# 2  198,500  18  2020  개포로 264  20210526.0
# 3  180,000   7  2020  개포로 264  20210526.0
# 4  210,000   5  2020  개포로 264         NaN

# %%
df = pd.concat([df_20,df_21])

# %%
df.head()
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    54.98  202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    79.97  202006   22
#
#   거래금액(만원)  층  건축년도      도로명  해제사유발생일
# 0  149,500  4  1988  언주로 103      NaN
# 1  144,000  4  1987    언주로 3      NaN
# 2  162,750  4  1987    언주로 3      NaN
# 3  160,000  5  1987    언주로 3      NaN
# 4  150,000  2  1987    언주로 3      NaN

# %%
df.tail()
# Out:
#                  시군구      번지     본번    부번      단지명  전용면적(㎡)    계약년월  계약일  \
# 29918  서울특별시 중랑구 중화동     450  450.0   0.0      한신2    59.76  202104   10
# 29919  서울특별시 중랑구 중화동     450  450.0   0.0      한신2    59.76  202104   16
# 29920  서울특별시 중랑구 중화동  274-51  274.0  51.0  한영(101)    57.66  202102   27
# 29921  서울특별시 중랑구 중화동  274-75  274.0  75.0  한영(102)    72.22  202105    4
# 29922  서울특별시 중랑구 중화동  274-76  274.0  76.0  한영(103)    58.46  202107    1
#
#       거래금액(만원)   층  건축년도         도로명  해제사유발생일
# 29918   66,000   6  1998     동일로 752      NaN
# 29919   68,000  13  1998     동일로 752      NaN
# 29920   30,500   5  2003  동일로144길 74      NaN
# 29921   49,500   4  2003  동일로144길 74      NaN
# 29922   30,000   2  2003  동일로144길 74      NaN

# %%
apart = pd.read_csv('./Apart_Deal.csv')
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
apart.head()
# Out:
#     지역코드  법정동             거래일       아파트     지번      전용면적   층  건축년도   거래금액
# 0  31110  학성동  5/30/2020 0:00    남운학성타운    379  135.5800   8  1991  26700
# 1  31110  남외동   1/3/2020 0:00  남외푸르지오1차  506-1  101.6000   2  2006  35500
# 2  31110  남외동   1/3/2020 0:00     에일린의뜰    500   84.9920  11  2007  36500
# 3  31110  남외동   1/3/2020 0:00  남외푸르지오1차  506-1  118.7060   8  2006  43000
# 4  31110  남외동   1/4/2020 0:00  남외푸르지오2차  501-1   84.9636   7  2007  38700

# %%
total = pd.read_csv('./dong_total.txt', sep='\t')

# %%
total.head()
# Out:
#         법정동코드           법정동명 폐지여부
# 0  1100000000          서울특별시   존재
# 1  1111000000      서울특별시 종로구   존재
# 2  1111010100  서울특별시 종로구 청운동   존재
# 3  1111010200  서울특별시 종로구 신교동   존재
# 4  1111010300  서울특별시 종로구 궁정동   존재

# %% [markdown]
# ## seoul_Apart EDA

# %%
df.columns = ['location', 'bun', 'bun_1', 'bun_2', 'name', 'square', 'date_ym', 'day', 'cost', 'floor', 'blit_year', 'road_name', 'de']

# %%
df.head()
# Out:
#         location    bun  bun_1  bun_2            name  square  date_ym  day  \
# 0  서울특별시 강남구 개포동  655-2  655.0    2.0  개포2차현대아파트(220)   77.75   202006   23
# 1  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   54.98   202002   24
# 2  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   18
# 3  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   20
# 4  서울특별시 강남구 개포동  658-1  658.0    1.0  개포6차우성아파트1동~8동   79.97   202006   22
#
#       cost  floor  blit_year road_name  de
# 0  149,500      4       1988   언주로 103 NaN
# 1  144,000      4       1987     언주로 3 NaN
# 2  162,750      4       1987     언주로 3 NaN
# 3  160,000      5       1987     언주로 3 NaN
# 4  150,000      2       1987     언주로 3 NaN

# %%
seoul = df.drop(['bun', 'bun_1', 'bun_2', 'day', 'road_name', 'de'],axis=1)

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987

# %%
len(seoul.location.unique())
# Out:
# 329

# %%
# 주소 분할 군, 동
seoul['gu'] = seoul.location.str.split(' ').str[1]
seoul['dong'] = seoul.location.str.split(' ').str[2]

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong
# 0  강남구  개포동
# 1  강남구  개포동
# 2  강남구  개포동
# 3  강남구  개포동
# 4  강남구  개포동

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   location   114149 non-null  object
#  1   name       114149 non-null  object
#  2   square     114149 non-null  float64
#  3   date_ym    114149 non-null  int64
#  4   cost       114149 non-null  object
#  5   floor      114149 non-null  int64
#  6   blit_year  114149 non-null  int64
#  7   gu         114149 non-null  object
#  8   dong       114149 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 8.7+ MB

# %%
seoul.isnull().sum()
# Out:
# location     0
# name         0
# square       0
# date_ym      0
# cost         0
# floor        0
# blit_year    0
# gu           0
# dong         0
# dtype: int64

# %%
# 구별 빈도수
count_gu = seoul.gu.value_counts()

# %%
count_gu = pd.DataFrame(count_gu).reset_index()

# %%
count_gu.plot.bar(x='index', y='gu', rot=0)
plt.show()
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49569 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 48393 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 48513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 52380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46993 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51089 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47560 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50501 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45432 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49569 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 48393 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 48513 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46993 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51089 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 47560 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50501 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
count_gu
# Out:
#    index     gu
# 0    노원구  12066
# 1    강서구   7796
# 2    구로구   6940
# 3    송파구   6059
# 4    도봉구   5995
# 5    성북구   5966
# 6    강동구   5637
# 7    강남구   5465
# 8    서초구   4859
# 9    양천구   4851
# 10  영등포구   4676
# 11   은평구   4537
# 12  동대문구   4417
# 13   성동구   4029
# 14   중랑구   4009
# 15   동작구   3936
# 16   마포구   3839
# 17  서대문구   3697
# 18   관악구   3668
# 19   강북구   2848
# 20   금천구   2370
# 21   용산구   2158
# 22   광진구   1783
# 23    중구   1468
# 24   종로구   1080

# %%
# 판매 년도, 연식 계산

seoul['sale_y'] = seoul.date_ym.astype(str).str[:4].astype(int)

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   location   114149 non-null  object
#  1   name       114149 non-null  object
#  2   square     114149 non-null  float64
#  3   date_ym    114149 non-null  int64
#  4   cost       114149 non-null  object
#  5   floor      114149 non-null  int64
#  6   blit_year  114149 non-null  int64
#  7   gu         114149 non-null  object
#  8   dong       114149 non-null  object
#  9   sale_y     114149 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 9.6+ MB

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong  sale_y
# 0  강남구  개포동    2020
# 1  강남구  개포동    2020
# 2  강남구  개포동    2020
# 3  강남구  개포동    2020
# 4  강남구  개포동    2020

# %%
seoul['used_y'] = seoul['sale_y']-seoul['blit_year']

# %%
seoul.head()
# Out:
#         location            name  square  date_ym     cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149,500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144,000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162,750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160,000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150,000      2       1987
#
#     gu dong  sale_y  used_y
# 0  강남구  개포동    2020      32
# 1  강남구  개포동    2020      33
# 2  강남구  개포동    2020      33
# 3  강남구  개포동    2020      33
# 4  강남구  개포동    2020      33

# %%
# 가격 숫자형으로 변환 ','삭제
seoul["cost"] = df["cost"].str.replace(pat=r'[^\w]', repl=r'', regex=True).astype(int)

# %%
seoul.head()
# Out:
#         location            name  square  date_ym    cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150000      2       1987
#
#     gu dong  sale_y  used_y
# 0  강남구  개포동    2020      32
# 1  강남구  개포동    2020      33
# 2  강남구  개포동    2020      33
# 3  강남구  개포동    2020      33
# 4  강남구  개포동    2020      33

# %%
# 평단가 계산
seoul['per_cost_man'] = seoul['cost'] / seoul['square']

# %%
seoul.head()
# Out:
#         location            name  square  date_ym    cost  floor  blit_year  \
# 0  서울특별시 강남구 개포동  개포2차현대아파트(220)   77.75   202006  149500      4       1988
# 1  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   54.98   202002  144000      4       1987
# 2  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  162750      4       1987
# 3  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  160000      5       1987
# 4  서울특별시 강남구 개포동  개포6차우성아파트1동~8동   79.97   202006  150000      2       1987
#
#     gu dong  sale_y  used_y  per_cost_man
# 0  강남구  개포동    2020      32   1922.829582
# 1  강남구  개포동    2020      33   2619.134231
# 2  강남구  개포동    2020      33   2035.138177
# 3  강남구  개포동    2020      33   2000.750281
# 4  강남구  개포동    2020      33   1875.703389

# %%
# 테이블 정리
seoul = seoul[['location', 'gu', 'dong', 'date_ym', 'blit_year', 'sale_y', 'used_y', 'square', 'per_cost_man', 'name', 'floor', 'cost']]

# %%
seoul.head()
# Out:
#         location   gu dong  date_ym  blit_year  sale_y  used_y  square  \
# 0  서울특별시 강남구 개포동  강남구  개포동   202006       1988    2020      32   77.75
# 1  서울특별시 강남구 개포동  강남구  개포동   202002       1987    2020      33   54.98
# 2  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
# 3  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
# 4  서울특별시 강남구 개포동  강남구  개포동   202006       1987    2020      33   79.97
#
#    per_cost_man            name  floor    cost
# 0   1922.829582  개포2차현대아파트(220)      4  149500
# 1   2619.134231  개포6차우성아파트1동~8동      4  144000
# 2   2035.138177  개포6차우성아파트1동~8동      4  162750
# 3   2000.750281  개포6차우성아파트1동~8동      5  160000
# 4   1875.703389  개포6차우성아파트1동~8동      2  150000

# %%
seoul_1 = seoul.drop(['location', 'date_ym', 'blit_year', 'sale_y'], axis=1)

# %%
seoul_1.head()
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor    cost
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4  149500
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4  144000
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4  162750
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5  160000
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2  150000

# %%
seoul_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114149 entries, 0 to 29922
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gu            114149 non-null  object
#  1   dong          114149 non-null  object
#  2   used_y        114149 non-null  int64
#  3   square        114149 non-null  float64
#  4   per_cost_man  114149 non-null  float64
#  5   name          114149 non-null  object
#  6   floor         114149 non-null  int64
#  7   cost          114149 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 7.8+ MB

# %%
# 아파트 명 단어 추출
seoul_1['token'] = seoul_1["name"].str.replace(pat=r'[아파트]|[^\w]|[0-9]|[동]', repl=r'', regex=True).str.split('차').str[-1]

# %%
seoul_1.head()
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor    cost  \
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4  149500
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4  144000
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4  162750
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5  160000
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2  150000
#
#   token  YN_r temp  YN_top10
# 0    현대     1   개포         0
# 1    우성     1   개포         0
# 2    우성     1   개포         0
# 3    우성     1   개포         0
# 4    우성     1   개포         0

# %%
seoul_1['YN_r'] = 0
seoul_1['temp'] = seoul_1['dong'].str.replace(pat=r'[동]', repl=r'', regex=True)

# %%
dong_list = list(seoul_1['temp'].unique())

# %%
for i in dong_list:
     seoul_1.loc[seoul_1['name'].str.contains(i), 'YN_r'] = 1

# %%
seoul_1['token'].value_counts()[:11]
# Out:
#           6551
# 상계주공고층    2392
# 현대        2315
# 주공        1618
# 신         1492
# 한신        1242
# 우성        1212
# 목신시가지     1057
# 두산         955
# 벽산         836
# 삼성래미안      766
# Name: token, dtype: int64

# %%
seoul_1['YN_top10'] = 0

# %%
top_list = ['상계주공고층', '현대', '주공', '신', '한신', '우성', '목신시가지', '두산', '벽산', '삼성래미안']

# %%
for i in top_list:
     seoul_1.loc[seoul_1['name'].str.contains(i), 'YN_top10'] = 1

# %%
seoul_1.head(5)
# Out:
#     gu dong  used_y  square  per_cost_man            name  floor    cost  \
# 0  강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4  149500
# 1  강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4  144000
# 2  강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4  162750
# 3  강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5  160000
# 4  강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2  150000
#
#   token  YN_r temp  YN_top10
# 0    현대     1   개포         1
# 1    우성     1   개포         1
# 2    우성     1   개포         1
# 3    우성     1   개포         1
# 4    우성     1   개포         1

# %%
seoul_1.groupby('dong')['cost'].agg('mean').sort_values(ascending=False)
# Out:
# dong
# 신문로2가     321500.000000
# 압구정동      317315.647482
# 반포동       278913.077935
# 용산동5가     254241.228070
# 서빙고동      227587.500000
#               ...
# 충신동        15637.500000
# 영등포동4가     14300.000000
# 원남동        13830.695652
# 영등포동3가     11553.846154
# 장충동2가      10441.666667
# Name: cost, Length: 327, dtype: float64

# %%
seoul_1.groupby('dong')['cost'].agg('median').sort_values(ascending=False)
# Out:
# dong
# 신문로2가     340500.0
# 장충동1가     304000.0
# 압구정동      281500.0
# 반포동       266000.0
# 서빙고동      243000.0
#             ...
# 영등포동2가     13600.0
# 영등포동1가     13500.0
# 원남동        13373.0
# 영등포동3가     11700.0
# 장충동2가      10725.0
# Name: cost, Length: 327, dtype: float64

# %%
seoul_1
# Out:
#         gu dong  used_y  square  per_cost_man            name  floor    cost  \
# 0      강남구  개포동      32   77.75   1922.829582  개포2차현대아파트(220)      4  149500
# 1      강남구  개포동      33   54.98   2619.134231  개포6차우성아파트1동~8동      4  144000
# 2      강남구  개포동      33   79.97   2035.138177  개포6차우성아파트1동~8동      4  162750
# 3      강남구  개포동      33   79.97   2000.750281  개포6차우성아파트1동~8동      5  160000
# 4      강남구  개포동      33   79.97   1875.703389  개포6차우성아파트1동~8동      2  150000
# ...    ...  ...     ...     ...           ...             ...    ...     ...
# 29918  중랑구  중화동      23   59.76   1104.417671             한신2      6   66000
# 29919  중랑구  중화동      23   59.76   1137.884873             한신2     13   68000
# 29920  중랑구  중화동      18   57.66    528.962886         한영(101)      5   30500
# 29921  중랑구  중화동      18   72.22    685.405705         한영(102)      4   49500
# 29922  중랑구  중화동      18   58.46    513.171399         한영(103)      2   30000
#
#       token  YN_r temp  YN_top10
# 0        현대     1   개포         1
# 1        우성     1   개포         1
# 2        우성     1   개포         1
# 3        우성     1   개포         1
# 4        우성     1   개포         1
# ...     ...   ...  ...       ...
# 29918    한신     0   중화         1
# 29919    한신     0   중화         1
# 29920    한영     0   중화         0
# 29921    한영     0   중화         0
# 29922    한영     0   중화         0
#
# [114149 rows x 12 columns]

# %%
seoul_1.to_csv('seoul_1.csv')

# %%
seoul_2 = pd.DataFrame(pd.read_csv('./seoul_1.csv'))

# %%
seoul_2
# Out:
#         Unnamed: 0   gu dong  used_y  square  ...    cost token  YN_r  temp YN_top10
# 0                0  강남구  개포동      32   77.75  ...  149500    현대     1    개포        1
# 1                1  강남구  개포동      33   54.98  ...  144000    우성     1    개포        1
# 2                2  강남구  개포동      33   79.97  ...  162750    우성     1    개포        1
# 3                3  강남구  개포동      33   79.97  ...  160000    우성     1    개포        1
# 4                4  강남구  개포동      33   79.97  ...  150000    우성     1    개포        1
# ...            ...  ...  ...     ...     ...  ...     ...   ...   ...   ...      ...
# 114144       29918  중랑구  중화동      23   59.76  ...   66000    한신     0    중화        1
# 114145       29919  중랑구  중화동      23   59.76  ...   68000    한신     0    중화        1
# 114146       29920  중랑구  중화동      18   57.66  ...   30500    한영     0    중화        0
# 114147       29921  중랑구  중화동      18   72.22  ...   49500    한영     0    중화        0
# 114148       29922  중랑구  중화동      18   58.46  ...   30000    한영     0    중화        0
#
# [114149 rows x 13 columns]

# %%
gu_cost = pd.DataFrame(pd.read_csv('./gu_cost.csv'))
used_count = pd.DataFrame(pd.read_csv('./used_count.csv'))

# %%
gu_cost.columns = ['gu', 'cost_mean per gu']

# %%
gu_cost.info()
seoul_2.info()
used_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gu                25 non-null     object
#  1   cost_mean per gu  25 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 528.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114149 entries, 0 to 114148
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    114149 non-null  int64
#  1   gu            114149 non-null  object
#  2   dong          114149 non-null  object
#  3   used_y        114149 non-null  int64
#  4   square        114149 non-null  float64
#  5   per_cost_man  114149 non-null  float64
#  6   name          114149 non-null  object
#  7   floor         114149 non-null  int64
#  8   cost          114149 non-null  int64
#  9   token         107598 non-null  object
#  10  YN_r          114149 non-null  int64
#  11  temp          114149 non-null  object
#  12  YN_top10      114149 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 11.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   used_y      59 non-null     int64
#  1   used_count  59 non-null     int64
# dtypes: int64(2)
# memory usage: 1.0 KB

# %%
seoul_2 = pd.merge(seoul_2, gu_cost, left_on='gu', right_on='gu', how='inner')

# %%
seoul_2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, gu, dong, used_y, square, per_cost_man, name, floor, cost, token, YN_r, temp, YN_top10, cost_mean per gu]
# Index: []

# %%
seoul_2 = pd.merge(seoul_2, used_count, left_on='used_y', right_on='used_y', how='inner')

# %%
seoul_2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, gu, dong, square, per_cost_man, name, floor, cost, token, YN_r, temp, YN_top10, cost_mean per gu, used_y, used_count]
# Index: []
