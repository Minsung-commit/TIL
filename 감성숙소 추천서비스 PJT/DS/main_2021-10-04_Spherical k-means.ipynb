# %%
import pandas as pd
import numpy as np
import re
import time
from kiwipiepy import Kiwi
import tomotopy as tp
from pyspark.conf import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
from pyspark.sql.functions import array_contains, udf
from datetime import datetime
# Word2Vec embedding
from gensim.models import Word2Vec
from numpy import dot
from numpy.linalg import norm
import numpy as np
from sklearn.cluster import KMeans
from textrank import KeywordSummarizer
from scipy.sparse import csr_matrix
from soyclustering import SphericalKMeans

#################################################################

def token(docs):
    return docs

def insta_preporcessing(insta):

    # 데이터 로드
    insta_data = pd.read_csv(insta)

    # 1차 클린징(영어, 특수문자, 숫자제거)
    for i in range(len(insta_data.content)):
        insta_data.content[i] = sub_special(insta_data.content[i])

    # 토큰화
    for i in range(len(insta_data.content)):
        insta_data.content[i]= tokenize(insta_data.content[i])

    # 2차 클린징(불용어 처리)
        word_cleansing(insta_data)

    return insta_data


def naver_preprocessing(naver):

    #데이터 로드
    naver_data = pd.read_csv(naver)

    # 인덱스 제거
    naver_data.drop('Unnamed: 0', axis=1, inplace=True)

    # 토큰화
    for i in range(len(naver_data)):
        naver_data.content[i] = sub_special_token(naver_data.content[i])

    #클린징
    word_cleansing(naver_data)

    return naver_data

def make_stopwords(input_text):
    with open (input_text, 'r', encoding= 'utf-8') as f:
        words = f.readline().split()
    stop_words = '의 가 이 은 들 는 좀 잘 속초 걍 과 했 거 해서 숙박 경기도 떠나다 느끼다 비애 댓글 권 만원 리조트 카라 추첨 즐기다 다녀오다 출처 여행 제공 감사 게 찍 느낌 많이 듯 뷰 박 링크 인스타그램 할인 성수기 홈페이지 주말 블로그 인원 추가 ㅎㅎ 너무 게스트 넘 하우스 드리다 이용 위치 쓰다 진짜 넘 찍 거 먹 ㅠㅠ ㅎㅎㅎ ㅠ 물 였 ㅠㅠㅠ ㅠㅠ ㅠ ㅋㅋㅋ ㅋㅋ ㅋ ㅎㅎㅎ ㅎㅎ ㅎ 화장실 도 뭐 오픈 최대 준비 룸 빵 거 많이 방법 달리 스럽다 특별자치도 를 에어비 으로 자 에 와 한 하다 아 휴 아이구 포스팅 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 이제 분 도움 여 ㅁ ㅎ ㄶ 얼마간 둥 오랜만 약간 체크 체크아웃 가격 정보 비 수기 평일 기준 약 전국  예약 되어다 스마트 빔 블루투스 스피커 이 외 드라이어 다리미 구비 되어다 있다 주방 음식 조리 가능하다 환기 제한 전남 제부도 있다 냄새 나 요리 삼가다 경주시 부탁드리다 후 번길 문의 다 가격 수기 비성수기 주소  좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 포항 우도 양양 전주시 통영 제천 여수시 순천 고성 합천 한림읍 전주 경북 구좌읍 돌산읍 태안 하동 포항시 제주시 밀양 양평 울산 무무 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 춘천 층 남해 스테이 서울 여수 거제 추천 경주 곳 객실 이다 강원도 강원 홍천 부산 영도 호 객실 교동 풀빌라 빌라 풀 스튜디오 펜션 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 감성 숙소 호텔 제주 제주도 강원도 강릉 속초 속초시 에어비앤비 명 생각 시간 그녀 수 약 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 사실 이렇 점 싶 말 정도 좀 원 잘 통하 ㅆ 재 채 독 롭 도란도 팅 감성비앤비 공간 참여 이벤트 당첨자 기간 부산 #부산숙소 #부산에어비앤비 #부산여행 경기 경주시 있는 한 #경주숙소 강원도 제주 제주시 #제주숙소 #제주감성숙소 #제주숙소추천 남해군 서면 춘천시 남해 광안리 편 반 안면도 산방산 님 사장 정말 공주 안동 충남 전라북도 충청남도 전북 실시간 퇴 활용 상품권 이메일 경상남도 날 꼭 찾다 직접 날 그냥 맘 근데 스타 욕 편 째 첫 맛 채 황리단 황리단길 미리 열다 거제도 공간 광안리 광안대교 스다 해운대 헤이 윤슬 울릉도 손 옆 홍보 입실시간 에디터경기도 캠핑 청주 가평 청도 포천 핑 강화도 근교 인천' #불용어 리스트 형성
    stop_words = stop_words.split(' ')
    stop_location = pd.read_csv('location_words.csv')
    stop_location.columns = ['index', 'location']
    stop_location = stop_location.location.tolist()

    stop = stop_words + stop_location + words
    stop = pd.Series(stop)
    stopwords = stop.unique().tolist()

    return stopwords

# 토크나이징 함수 정의 


# tokenize 함수를 정의합니다. 한국어 문장을 입력하면 형태소 단위로 분리하고, 
# 불용어 및 특수 문자 등을 제거한 뒤, list로 반환합니다.

def make_userdic(input_text):
    with open (input_text, 'r', encoding= 'utf-8') as f:
        words = f.readline().split()
    kiwi.add_user_word(words) # 사용자사전


# tokenize 함수를 정의합니다. 한국어 문장을 입력하면 형태소 단위로 분리하고, 
# 불용어 및 특수 문자 등을 제거한 뒤, list로 반환합니다.

def tokenize(sent):
    res, score = kiwi.analyze(sent)[0] # 첫번째 결과를 사용
    return [word + ('다' if tag.startswith('V') else '') # 동사에는 '다'를 붙여줌
            for word, tag, _, _ in res
            if not tag.startswith('E') and not tag.startswith('J') and not tag.startswith('S') and not tag.startswith('W') and word not in stopwords] # 조사, 어미, 특수기호 및 stopwords에 포함된 단어는 제거


def tokenize_nouns(sent):
    res, score = kiwi.analyze(sent)[0] # 첫번째 결과를 사용
    return [word + ('다' if tag.startswith('V') else '') # 동사에는 '다'를 붙여줌
            for word, tag, _, _ in res
            if tag.startswith('N')] # 조사, 어미, 특수기호 및 stopwords에 포함된 단어는 제거


"""인스타 데이터 전처리"""

#"""한글빼고 전부 제거"""
def sub_special(s):
    rs = re.sub(r'[^가-힣]',' ',s)
    rr = re.sub(' +', ' ', rs)
    return rr

#"""한글빼고 전부 제거"""
def sub_special_token(s):
    rs = re.sub(r'[^가-힣]',' ',s).strip().split()
    return rs

#불용어 제거
def word_cleansing(data): 
    for i in range(len(data)): 
        result = []
        for w in data.content[i]:
            if w not in stopwords:
                result.append(w)
    
        data.content[i] = result
        
def make_total_list(naver_data, insta_data):
    n_data = pd.DataFrame(naver_data.copy()) # 네이버 블로그 데이터 로드(콘텐츠)
    i_data = pd.DataFrame(insta_data[['index', 'content']].copy()) # 인스타 데이터 로드(인덱스, 콘텐츠)

    i_data.columns = ['item_idx', 'content'] # merge를 위한 식별자 컬럼('item_idx') 생성

    all_items = pd.concat([i_data, n_data]) # 두 데이터 행 병합

    all_items.reset_index(drop=True, inplace=True) #인덱스 리셋

    #빈 샘플 확인 및 제거

    drop = [index for index in range(len(all_items)) if len(all_items.content[index]) < 1] # drop에 empty 샘플의 인덱스를 저장


    while len(drop) > 0: 

        # 빈 샘플 제거
        for i in drop:
            all_items.drop(all_items.index[i], inplace=True)
        # 인덱스 리셋
        all_items.reset_index(drop=True, inplace=True)

        drop = [index for index in range(len(all_items)) if len(all_items.content[index]) < 1] # 재확인 

     # 인덱스 리셋
    all_items.reset_index(drop=True, inplace=True) #최종 리셋

    return all_items



def create_model(data, clusters_n):
    word_vectors = data['wv'].to_list() 
    num_clusters = clusters_n

    # K means 를 정의하고 학습시킨다.
    kmeans_clustering = KMeans(n_clusters=num_clusters, init='k-means++', n_init=25, max_iter = 600, random_state=0)
    idx = kmeans_clustering.fit_predict( word_vectors )
    data['category'] = idx
    
def get_sentence_mean_vector(morphs):
    vector = []
    for i in morphs:
        try:
            vector.append(embedding_model.wv[i])
        except KeyError as e:
            pass
    try:
        return sum(vector)/len(vector)
    except IndexError as e:
        pass
    
def token_dummy(docs):
    return docs

def embedding(data):
    embedding_model = Word2Vec(data.content, vector_size=100, window = 2, min_count=3, workers=4, epochs=100, sg=1)
    return embedding_model

def keyword_extractor():
    keyword_extractor = KeywordSummarizer(tokenize = token_dummy,
    min_count=5,
    window=8,                     # cooccurrence within a sentence
    min_cooccurrence=3,
    vocab_to_idx=None,             # you can specify vocabulary to build word graph
    df=0.85,                       # PageRank damping factor
    max_iter=30,                   # PageRank maximum iteration
    verbose=False)
    
    return keyword_extractor

def cos_sim(A, B):
       return dot(A, B)/(norm(A)*norm(B))

    
def create_matrix(data):
    wv_matrix = np.asarray(data.wv)
    rows = []
    matrix = []
    for i in range(len(data.content)):
        for x in range(len(data.content)):
            cos_sim = dot(wv_matrix[i], wv_matrix[x])/(norm(wv_matrix[i])*norm(wv_matrix[x]))
            rows.append(cos_sim)
        matrix.append(rows)
        rows=[]
    return matrix

def create_model_spherical(data, n_clusters):
    x = data.wv.to_list()
    x = np.asarray(x)
    csr = csr_matrix(x)
    spherical_kmeans = SphericalKMeans(
    n_clusters=n_clusters,
    max_iter=15,
    verbose=1,
    init='similar_cut')
    time.sleep(1)
    index = spherical_kmeans.fit_predict(csr)
    data['category'] = index
    
def token(docs):
    return docs


####################################################################################################

#데이터 로드
nowtime = datetime.today().strftime("%Y-%m-%d")
spark = SparkSession\
        .builder\
        .appName('aaa')\
        .getOrCreate()
insta_data = spark.read.parquet(f"hdfs://localhost:9000/data/modeldata/tot_dataset_2021-10-04.parquet")
insta_data = insta_data.toPandas()
insta_data.reset_index(inplace=True)
original = insta_data.content.copy()

####################################################################################################

#형태소 분석기 / 불용어리스트 생성
stoptext = './stopwords_korean.txt'
stopwords = make_stopwords(stoptext) #불용어 리스트 생성
user_word= '호캉스  호텔  힐링  독채숙소  독채  한옥  자연  오션뷰 외국 캠핑 바다 파티 럽스타 어메니티 빔프로젝트 빔 프로젝트 글램핑 풀빌라 노천탕 프라이빗 인피니티풀 루프탑 히노끼탕 히노끼 온수풀 수영장 숲속 숲 나무'
stoptext = './stopwords_korean.txt'
# naver = './total_blog_dataset.csv'
kiwi = Kiwi()
kiwi.add_user_word(user_word, 'NNP', 10)
kiwi.prepare()
time.sleep(10)
# 1차 클린징(영어, 특수문자, 숫자제거)
for i in range(len(insta_data.content)):
    insta_data.content[i] = sub_special(insta_data.content[i])
time.sleep(10)
# 토큰화
for i in range(len(insta_data.content)):
    insta_data.content[i]= tokenize(insta_data.content[i])
time.sleep(10)
# 2차 클린징(불용어 처리)
word_cleansing(insta_data)

time.sleep(1)

all_items = insta_data.copy()
time.sleep(5)
embedding_model = Word2Vec(all_items.content, vector_size=100, window = 2, min_count=3, workers=4, epochs=200, sg=1, seed=0)
time.sleep(5)
all_items['wv'] = all_items['content'].map(get_sentence_mean_vector)
time.sleep(5)
create_model_spherical(all_items, 10)
time.sleep(1)
all_items['content'] = insta_data.content
all_items['original_content'] = original

# create_model(all_items, 10)
# matrix = create_matrix(all_items)
# Out:
# /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:255: DeprecationWarning: `prepare()` has no effect and will be removed in future version.
# /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# initialization_time=0.004437 sec, sparsity=0.9
# n_iter=1, changed=679, inertia=135.325, iter_time=0.087 sec, sparsity=1.0
# n_iter=2, changed=161, inertia=83.531, iter_time=0.064 sec, sparsity=1.0
# n_iter=3, changed=72, inertia=80.441, iter_time=0.106 sec, sparsity=1.0
# n_iter=4, changed=39, inertia=79.017, iter_time=0.065 sec, sparsity=1.0
# n_iter=5, changed=20, inertia=78.534, iter_time=0.073 sec, sparsity=1.0
# n_iter=6, changed=19, inertia=78.296, iter_time=0.082 sec, sparsity=1.0
# n_iter=7, changed=13, inertia=78.114, iter_time=0.064 sec, sparsity=1.0
# n_iter=8, changed=13, inertia=77.965, iter_time=0.138 sec, sparsity=1.0
# n_iter=9, changed=7, inertia=77.870, iter_time=0.073 sec, sparsity=1.0
# n_iter=10, changed=2, inertia=77.822, iter_time=0.064 sec, sparsity=1.0
# n_iter=11, changed=1, inertia=77.800, iter_time=0.065 sec, sparsity=1.0
# Early converged.

# %%
test = all_items.copy()

# %%
word = []
for i in range(len(all_items)):
    word += all_items.content.iloc[i]
word
# Out:
# ['석주재프라이빗',
#  '한옥',
#  '주재',
#  '석주',
#  '프라이빗',
#  '한옥',
#  '하루',
#  '팀',
#  '조용',
#  '힐링',
#  '바베큐',
#  '장이',
#  '무쇠',
#  '솥',
#  '뚜껑',
#  '그리',
#  '가스',
#  '버너',
#  '취사',
#  '도구',
#  '간단',
#  '참고',
#  '목조',
#  '주택',
#  '특성',
#  '실내',
#  '불가',
#  '한옥',
#  '모든',
#  '부분',
#  '깔끔',
#  '힘들다',
#  '재료',
#  '약하다',
#  '쉽다',
#  '파손',
#  '이해',
#  '사용',
#  '탕',
#  '냉수',
#  '기름',
#  '보일러',
#  '사용',
#  '걱정',
#  '없이',
#  '프라이빗',
#  '사용',
#  '조용',
#  '한옥',
#  '보내다',
#  '추억',
#  '쌓다',
#  '주재',
#  '경남',
#  '곡',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '경남',
#  '컴온인',
#  '동남아',
#  '이국',
#  '분위기',
#  '컴온',
#  '컴',
#  '동남아',
#  '이국',
#  '분위기',
#  '가득',
#  '담다',
#  '아늑',
#  '관광',
#  '최적',
#  '자리',
#  '주요',
#  '관광지',
#  '카페',
#  '액티비',
#  '티',
#  '걷다',
#  '이내',
#  '최단',
#  '거리',
#  '커플',
#  '홀로',
#  '목적',
#  '만족',
#  '스럽',
#  '동남아',
#  '그립다',
#  '담다',
#  '마음',
#  '분위기',
#  '바라다',
#  '해외여행',
#  '어렵다',
#  '동남아',
#  '그립다',
#  '이국',
#  '분위기',
#  '담다',
#  '특별',
#  '아침',
#  '맞이',
#  '늘',
#  '분위기',
#  '다르다',
#  '일상',
#  '지루',
#  '떨치다',
#  '버리다',
#  '컴온인',
#  '힐링',
#  '보내다',
#  '컴',
#  '정확',
#  '비수기',
#  '데일리',
#  '데일리',
#  '전라남도',
#  '데일리',
#  '문',
#  '스톤',
#  '문',
#  '스톤',
#  '문',
#  '스톤',
#  '해수욕장',
#  '근처',
#  '깔끔',
#  '신축',
#  '카페',
#  '바베큐',
#  '운영',
#  '유리창',
#  '주차',
#  '주차',
#  '운영',
#  '카페',
#  '예쁘다',
#  '따로',
#  '카페',
#  '여유',
#  '보내다',
#  '높다',
#  '오피스텔',
#  '고급',
#  '스럽',
#  '인테리어',
#  '꾸미다',
#  '침대',
#  '눕다',
#  '바라보다',
#  '서해',
#  '바다',
#  '아름답다',
#  '바다',
#  '바라보다',
#  '힐링',
#  '문',
#  '스톤',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '고등어',
#  '민박',
#  '동쪽',
#  '로맨틱',
#  '고등어',
#  '민박',
#  '고등어',
#  '민박',
#  '푸르다',
#  '빛',
#  '바다',
#  '북동쪽',
#  '조용',
#  '바닷가',
#  '마을',
#  '터',
#  '잡다',
#  '고등어',
#  '처음',
#  '질리다',
#  '고급',
#  '스럽',
#  '특유',
#  '기억',
#  '짓다',
#  '이름',
#  '실',
#  '이루어지다',
#  '모든',
#  '구조',
#  '크기',
#  '아늑',
#  '휴식',
#  '침실',
#  '분리',
#  '차분',
#  '컬러',
#  '최소한',
#  '소품',
#  '채우다',
#  '모든',
#  '바다',
#  '눈',
#  '맑다',
#  '침실',
#  '멀리',
#  '한라산',
#  '동쪽',
#  '지역',
#  '숨다',
#  '명소',
#  '고등어',
#  '민박',
#  '배경',
#  '한적',
#  '해변',
#  '산책',
#  '음악',
#  '책',
#  '읽다',
#  '여유',
#  '힐링',
#  '보내다',
#  '고등어',
#  '민박',
#  '해맞이해안',
#  '비수기',
#  '데일리',
#  '데일리',
#  '청연',
#  '한옥스테',
#  '청연',
#  '청연',
#  '전주한옥마을',
#  '한옥',
#  '독채스테',
#  '한옥마을',
#  '흔하다',
#  '고가',
#  '높다',
#  '처마',
#  '늘어지다',
#  '한옥',
#  '대들보',
#  '사용',
#  '지붕',
#  '높다',
#  '쌓다',
#  '올리다',
#  '기존',
#  '한옥',
#  '접목',
#  '개방',
#  '한옥스테이로',
#  '모든',
#  '시설',
#  '단독',
#  '사용',
#  '한옥',
#  '특성',
#  '실내',
#  '취사',
#  '불가',
#  '참고',
#  '오후',
#  '일몰',
#  '부엌',
#  '들어오다',
#  '햇빛',
#  '아름답다',
#  '간단',
#  '디저트',
#  '저녁',
#  '따스',
#  '햇살',
#  '청연',
#  '완산구',
#  '전주천',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '숲',
#  '오두막',
#  '조용',
#  '숲',
#  '하루',
#  '숲',
#  '오두막',
#  '숲',
#  '오두막',
#  '여유',
#  '분위기',
#  '해발고도',
#  '숲',
#  '오두막',
#  '조용히',
#  '힐링',
#  '화려',
#  '세련',
#  '인테리어',
#  '오두막집',
#  '마음',
#  '편안',
#  '휴식',
#  '취하다',
#  '한적',
#  '숲',
#  '여유',
#  '고독',
#  '제대로',
#  '숲',
#  '오두막은불멍',
#  '바베큐',
#  '프로젝터',
#  '깜깜',
#  '숲',
#  '밖',
#  '테라스',
#  '숲',
#  '바라보다',
#  '커피',
#  '잔',
#  '모든',
#  '걱정',
#  '날아가다',
#  '기분',
#  '숲',
#  '내음',
#  '가득',
#  '휴식',
#  '취하다',
#  '잊다',
#  '하루',
#  '숲',
#  '오두막',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '갈곶힐링',
#  '예쁘다',
#  '갈다',
#  '곶',
#  '갈다',
#  '곶',
#  '바람',
#  '언덕',
#  '시원',
#  '그대',
#  '촬영',
#  '지인',
#  '숲',
#  '품다',
#  '예쁘다',
#  '바람',
#  '언덕',
#  '풍차가통창',
#  '눈',
#  '전체',
#  '리모델링',
#  '모던',
#  '깔끔',
#  '완성',
#  '전용',
#  '주차장',
#  '편하다',
#  '주차',
#  '실내',
#  '인테리어',
#  '나무',
#  '개방',
#  '건물',
#  '루프탑',
#  '이루어지다',
#  '펜션이라프라이빗',
#  '사용',
#  '침대',
#  '눕다',
#  '통창',
#  '바람',
#  '언덕',
#  '바라보다',
#  '편안',
#  '휴식',
#  '취하다',
#  '갈다',
#  '곶',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '경남',
#  '스테이스며들다',
#  '조용',
#  '스테이스며들',
#  '스테이스며들',
#  '조용',
#  '한적',
#  '바닷가',
#  '마을',
#  '부부',
#  '운영',
#  '민박',
#  '시골',
#  '마을',
#  '정취',
#  '가득',
#  '묻다',
#  '리',
#  '오래',
#  '농가',
#  '주택',
#  '사계절',
#  '온전',
#  '히',
#  '겪다',
#  '다듬다',
#  '담기다',
#  '아침',
#  '느릿느릿',
#  '일어나다',
#  '바다',
#  '마을',
#  '산책',
#  '저녁',
#  '차귀도',
#  '배경',
#  '아름답다',
#  '노을',
#  '감상',
#  '밤',
#  '라운지',
#  '기분',
#  '술',
#  '기울이다',
#  '음악',
#  '듣다',
#  '책',
#  '읽다',
#  '오롯',
#  '게스트분들과의소소',
#  '어울리다',
#  '답답',
#  '도시',
#  '벗어나다',
#  '조용',
#  '한적',
#  '용수리의스테이스며들다',
#  '여유',
#  '보내다',
#  '스며들다',
#  '비수기',
#  '데일리',
#  '데일리',
#  '황오감성',
#  '전통',
#  '아름다움',
#  '한옥',
#  '오감',
#  '황오감',
#  '리모델링한깨긋',
#  '주변',
#  '황룡사',
#  '터',
#  '동궁',
#  '박물관',
#  '관광지',
#  '가까이',
#  '인접',
#  '도보',
#  '걸리다',
#  '유명',
#  '관광지',
#  '카페',
#  '구경',
#  '편하다',
#  '전체',
#  '정겨운',
#  '민박',
#  '총',
#  '이루어지다',
#  '따로',
#  '사용',
#  '공동',
#  '시설',
#  '마당',
#  '평상',
#  '항아리',
#  '정겨운',
#  '소품',
#  '옛',
#  '시골집',
#  '할머니',
#  '댁',
#  '한옥',
#  '옛',
#  '이루다',
#  '저렴',
#  '한옥',
#  '황오감성',
#  '조용',
#  '휴식',
#  '취하다',
#  '임해로',
#  '비수기',
#  '데일리',
#  '데일리',
#  '경상북도',
#  '데일리',
#  '한가',
#  '분위기',
#  '한가',
#  '한가',
#  '로운',
#  '이루어지다',
#  '프라이빗',
#  '블럭',
#  '쏟아지다',
#  '따뜻',
#  '햇살',
#  '한가',
#  '기분',
#  '만끽',
#  '따뜻',
#  '포근',
#  '베이지',
#  '우드',
#  '톤',
#  '인테리어',
#  '사용',
#  '출입구',
#  '연결',
#  '보도',
#  '통로',
#  '조명',
#  '시설',
#  '밤',
#  '불편',
#  '없이',
#  '다니다',
#  '근처',
#  '대형',
#  '마트',
#  '다양',
#  '편의',
#  '시설',
#  '편하다',
#  '사용',
#  '정원',
#  '매력',
#  '한가에서힐링',
#  '보내다',
#  '한가',
#  '완산구',
#  '비수기',
#  '데일리',
#  '데일리',
#  '인연',
#  '한옥',
#  '편리',
#  '현대',
#  '감각',
#  '인연',
#  '인연',
#  '포석로',
#  '골목길',
#  '년대',
#  '낡다',
#  '건물',
#  '그대로',
#  '보존',
#  '옛',
#  '정취',
#  '번화가',
#  '걷다',
#  '거리',
#  '한옥',
#  '인연',
#  '옛',
#  '정취',
#  '고스',
#  '히',
#  '카페',
#  '식당',
#  '편리',
#  '근처',
#  '첨성대',
#  '대릉',
#  '관광지',
#  '둘러보다',
#  '프리미엄',
#  '프리미어',
#  '빔프로젝터',
#  '스타일',
#  '모션',
#  '침대',
#  '커피',
#  '머신',
#  '배치',
#  '다양',
#  '편리',
#  '경험',
#  '모든',
#  '독립',
#  '구조',
#  '기존',
#  '한옥',
#  '넓다',
#  '마당',
#  '공용',
#  '없애다',
#  '개별',
#  '입구',
#  '마당',
#  '프라이',
#  '빗',
#  '선사',
#  '인연',
#  '첨성로',
#  '비수기',
#  '데일리',
#  '데일리',
#  '경상북도',
#  '데일리',
#  '바람',
#  '꽃',
#  '갯벌',
#  '유럽',
#  '바람꽃',
#  '바람',
#  '꽃',
#  '바닷가',
#  '포구',
#  '마을',
#  '나무',
#  '하루',
#  '씩',
#  '밀물',
#  '썰물이첨벙',
#  '소리',
#  '들리다',
#  '바다',
#  '가깝다',
#  '트다',
#  '모습',
#  '노을',
#  '구름',
#  '모습',
#  '걷다',
#  '작당',
#  '포구',
#  '마을',
#  '해변',
#  '내려가다',
#  '드넓다',
#  '갯벌',
#  '밀물',
#  '썰물',
#  '계절',
#  '다르다',
#  '풍경',
#  '연출',
#  '나무',
#  '욕조',
#  '바다',
#  '바라보다',
#  '바닷바람',
#  '불다',
#  '바라보다',
#  '잠',
#  '시시각각',
#  '풍경',
#  '변하다',
#  '드넚',
#  '갯벌',
#  '산책',
#  '탐험',
#  '즐거움',
#  '누리다',
#  '바람',
#  '꽃',
#  '당기다',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '한옥',
#  '전통',
#  '한옥',
#  '한옥',
#  '한옥',
#  '넓다',
#  '최근',
#  '신축',
#  '건물',
#  '이루어지다',
#  '전통',
#  '급',
#  '한옥',
#  '남측',
#  '고급',
#  '스럽',
#  '화려',
#  '북측',
#  '첨성대',
#  '옛',
#  '골목',
#  '뒷문',
#  '아름답다',
#  '협문',
#  '문',
#  '대릉원',
#  '쉽다',
#  '드나들다',
#  '갤러리',
#  '사용',
#  '한옥',
#  '체험',
#  '실',
#  '카페',
#  '식당',
#  '전통',
#  '실',
#  '다양',
#  '볼거리',
#  '아름',
#  '편안',
#  '가까이',
#  '한옥',
#  '마을',
#  '파노라마',
#  '멀리',
#  '대릉',
#  '오릉',
#  '첨성대',
#  '전체',
#  '조망',
#  '아늑',
#  '잔디',
#  '마당',
#  '넓다',
#  '데크',
#  '휴식',
#  '취하다',
#  '담장',
#  '뒤뜰에서힐링',
#  '한옥',
#  '포석로',
#  '비수기',
#  '데일리',
#  '데일리',
#  '경상북도',
#  '데일리',
#  '내도모해',
#  '아름',
#  '섬',
#  '힐링',
#  '모해',
#  '모해',
#  '우리말',
#  '모퉁이',
#  '비추다',
#  '햇살',
#  '뜻',
#  '모해',
#  '소박',
#  '따뜻',
#  '이름',
#  '모해',
#  '짓다',
#  '화려',
#  '따뜻',
#  '가득',
#  '일상',
#  '지치다',
#  '몸',
#  '마음',
#  '달래다',
#  '휴식',
#  '취하다',
#  '이용료',
#  '거리',
#  '짐',
#  '걱정',
#  '바다',
#  '눈',
#  '펼쳐지다',
#  '섬',
#  '한적',
#  '조용',
#  '쉬다',
#  '카페',
#  '운영',
#  '커피',
#  '근처',
#  '산책',
#  '모해',
#  '경남',
#  '비수기',
#  '데일리감성거제',
#  '데일리',
#  '데일리',
#  '경남',
#  '파도의무늬오션뷰',
#  '무늬',
#  '무늬',
#  '물결',
#  '일렁이다',
#  '반짝거리다',
#  '철썩',
#  '철썩',
#  '치다',
#  '다양',
#  '모습',
#  '무늬',
#  '들려오다',
#  '시원',
#  '소리',
#  '가만히',
#  '눈',
#  '듣다',
#  '계획',
#  '느긋',
#  '머리',
#  '식히다',
#  '세',
#  '엿보이다',
#  '푸르다',
#  '무늬',
#  '오후',
#  '저녁',
#  '들어오다',
#  '따뜻',
#  '영랑호',
#  '햇살',
#  '그대로',
#  '담다',
#  '바다',
#  '오션뷰에',
#  '욕실',
#  '분리',
#  '눈',
#  '소리',
#  '듣다',
#  '티',
#  '스트레스',
#  '티',
#  '복잡',
#  '마음',
#  '해소',
#  '무늬',
#  '정확',
#  '표시',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '조히경',
#  '한옥',
#  '조',
#  '히',
#  '조',
#  '히',
#  '한옥',
#  '한옥',
#  '유지',
#  '편리',
#  '거실',
#  '서가래',
#  '살리다',
#  '한옥',
#  '정취',
#  '그대로',
#  '오래',
#  '시설',
#  '깔끔',
#  '은은',
#  '틀다',
#  '프로젝터',
#  '독채',
#  '사용',
#  '마당',
#  '피크닉',
#  '발뮤',
#  '토스터',
#  '기와',
#  '캡슐',
#  '커피',
#  '머신',
#  '도구',
#  '조미료',
#  '다양',
#  '식기',
#  '잔',
#  '종류',
#  '술',
#  '맞다',
#  '식기',
#  '사용',
#  '조',
#  '히',
#  '원효로',
#  '비수기',
#  '데일리',
#  '데일리',
#  '경상북도',
#  '데일리',
#  '시호일시간',
#  '흔적',
#  '담다',
#  '시호',
#  '시호',
#  '년대',
#  '번화가',
#  '유명',
#  '흔적',
#  '품다',
#  '주택',
#  '상점',
#  '동네',
#  '상점',
#  '주택가',
#  '만나다',
#  '지점',
#  '조용히',
#  '자리',
#  '오래',
#  '주택',
#  '형태',
#  '유지',
#  '미니',
#  '멀다',
#  '베이스',
#  '빈티지',
#  '요소',
#  '입히다',
#  '시호',
#  '독특',
#  '분위기',
#  '물줄기',
#  '바다',
#  '흘러가다',
#  '남대천',
#  '내려오다',
#  '물고기',
#  '바다',
#  '밀려오다',
#  '물고기',
#  '새',
#  '눈',
#  '따스',
#  '아침',
#  '햇살',
#  '맞다',
#  '일어나다',
#  '남대천',
#  '산책',
#  '동네',
#  '아기자기',
#  '가게',
#  '카페',
#  '구경',
#  '보내다',
#  '시호',
#  '경강로',
#  '비수기',
#  '데일리',
#  '데일리',
#  '데일리',
#  '스테이시호',
#  '추',
#  '예쁘다',
#  '까맣다',
#  '돌멩이',
#  '조식',
#  '예쁘다',
#  '까맣다',
#  '돌멩이',
#  '까맣다',
#  '돌멩이',
#  '가족',
#  '커플',
#  '여행객',
#  '원룸',
#  '형',
#  '식',
#  '민박',
#  '옛',
#  '돌',
#  '살리다',
#  '리모델링',
#  '힐링',
#  '조용',
#  ...]

# %%
from collections import Counter

a = dict(Counter(word))

# %%
keywords
# Out:
# [('바다', 369),
#  ('한옥', 355),
#  ('힐링', 283),
#  ('수영장', 274),
#  ('비수기', 273),
#  ('바라보다', 264),
#  ('가득', 261),
#  ('가족', 234),
#  ('인테리어', 208),
#  ('카페', 205),
#  ('넓다', 203),
#  ('따뜻', 199),
#  ('마을', 198),
#  ('조용', 195),
#  ('국내', 195),
#  ('침실', 188),
#  ('보내다', 184),
#  ('오션뷰', 184),
#  ('데일리', 176),
#  ('바베큐', 175),
#  ('계획', 175),
#  ('예쁘다', 174),
#  ('분위기', 173),
#  ('아름답다', 173),
#  ('거실', 173),
#  ('호캉', 173),
#  ('하루', 165),
#  ('매력', 165),
#  ('풍경', 163),
#  ('여유', 160),
#  ('경남', 159),
#  ('마음', 155),
#  ('야외', 155),
#  ('기록', 155),
#  ('휴식', 154),
#  ('편안', 153),
#  ('꾸미다', 150),
#  ('조식', 150),
#  ('여행지', 150),
#  ('아늑', 149),
#  ('마당', 145),
#  ('이쁘다', 142),
#  ('탕', 137),
#  ('햇살', 137),
#  ('숲', 136),
#  ('소리', 135),
#  ('소품', 133),
#  ('다양', 132),
#  ('갖추다', 132),
#  ('깔끔', 129),
#  ('하늘', 128),
#  ('정원', 127),
#  ('사용', 123),
#  ('담다', 123),
#  ('커플', 122),
#  ('문', 121),
#  ('프라이빗', 118),
#  ('테라스', 118),
#  ('누리다', 118),
#  ('주변', 115),
#  ('친구', 115),
#  ('거리', 114),
#  ('독채', 110),
#  ('경상북도', 107),
#  ('주인장', 107),
#  ('추억', 106),
#  ('오롯', 106),
#  ('바람', 103),
#  ('노을', 102),
#  ('쉬다', 102),
#  ('나누다', 102),
#  ('밤', 101),
#  ('화이트', 101),
#  ('트이다', 101),
#  ('핫', 101),
#  ('개별', 99),
#  ('아기자기', 98),
#  ('운영', 97),
#  ('총', 97),
#  ('나무', 96),
#  ('민박', 95),
#  ('스파', 95),
#  ('제주독채', 94),
#  ('연인', 93),
#  ('이야기', 88),
#  ('프다', 87),
#  ('톤', 86),
#  ('욕조', 86),
#  ('곳곳', 86),
#  ('선물', 86),
#  ('만끽', 85),
#  ('산', 85),
#  ('히', 82),
#  ('모든', 81),
#  ('일상', 80),
#  ('들어오다', 80),
#  ('앉다', 80),
#  ('없이', 77),
#  ('커피', 77),
#  ('스럽', 75),
#  ('이루어지다', 75),
#  ('계절', 75),
#  ('쌓이다', 75),
#  ('피로', 75),
#  ('전체', 74),
#  ('그대로', 74),
#  ('만나다', 74),
#  ('취하다', 72),
#  ('밖', 72),
#  ('포근', 72),
#  ('머무르다', 72),
#  ('푸르다', 71),
#  ('실내', 69),
#  ('벗어나다', 69),
#  ('자쿠지', 69),
#  ('고르다', 69),
#  ('배경', 68),
#  ('흐름', 68),
#  ('팀', 67),
#  ('산책', 66),
#  ('시설', 66),
#  ('시골', 66),
#  ('두르다', 66),
#  ('멋지다', 65),
#  ('인생', 64),
#  ('리', 63),
#  ('욕실', 63),
#  ('맞다', 63),
#  ('더욱', 63),
#  ('일출', 63),
#  ('자리', 62),
#  ('동쪽', 62),
#  ('한적', 62),
#  ('해변', 62),
#  ('어우러지다', 62),
#  ('쉼', 62),
#  ('펼쳐지다', 61),
#  ('서쪽', 61),
#  ('제작', 61),
#  ('들어가다', 61),
#  ('취향', 61),
#  ('확', 61),
#  ('감상', 60),
#  ('돌담', 60),
#  ('침대', 59),
#  ('책', 59),
#  ('온전', 59),
#  ('물놀이', 59),
#  ('아침', 58),
#  ('전라남도', 58),
#  ('따스', 58),
#  ('그림', 58),
#  ('프라이', 57),
#  ('가깝다', 57),
#  ('근처', 56),
#  ('새소리', 56),
#  ('형', 55),
#  ('나뉘다', 55),
#  ('창문', 55),
#  ('태그해', 55),
#  ('콘탠츠', 55),
#  ('해수욕장', 54),
#  ('실', 54),
#  ('담기다', 54),
#  ('우드', 54),
#  ('여름', 54),
#  ('빛', 53),
#  ('눈', 53),
#  ('빗', 53),
#  ('우드톤', 53),
#  ('껏', 52),
#  ('피크닉', 51),
#  ('고즈넉', 51),
#  ('듣다', 50),
#  ('인피니티', 50),
#  ('참고', 49),
#  ('이국', 49),
#  ('관광지', 49),
#  ('특별', 49),
#  ('짓다', 49),
#  ('구조', 49),
#  ('모습', 49),
#  ('기분', 48),
#  ('감각', 48),
#  ('머물다', 48),
#  ('건물', 47),
#  ('놀다', 47),
#  ('편하다', 46),
#  ('잔디', 46),
#  ('테이블', 45),
#  ('사계절', 44),
#  ('조명', 44),
#  ('샷', 44),
#  ('높다', 43),
#  ('유명', 43),
#  ('잡다', 42),
#  ('지치다', 42),
#  ('포인트', 42),
#  ('꽃', 41),
#  ('배려', 41),
#  ('눕다', 40),
#  ('시원', 40),
#  ('쏟아지다', 40),
#  ('몸', 40),
#  ('풀장', 40),
#  ('그램', 40),
#  ('국내외', 40),
#  ('채우다', 39),
#  ('모던', 39),
#  ('유럽', 39),
#  ('아름', 39),
#  ('정성', 39),
#  ('바라다', 38),
#  ('키즈', 38),
#  ('해외', 38),
#  ('취사', 36),
#  ('간단', 36),
#  ('빔프로젝터', 36),
#  ('체험', 36),
#  ('완벽', 36),
#  ('식물', 36),
#  ('포토존', 36),
#  ('물씬', 36),
#  ('별장', 36),
#  ('단독', 35),
#  ('일몰', 35),
#  ('뜻', 35),
#  ('먼저', 35),
#  ('현대', 34),
#  ('데이트', 34),
#  ('탁', 34),
#  ('주택', 33),
#  ('언덕', 33),
#  ('전통', 33),
#  ('가만히', 33),
#  ('빈티지', 33),
#  ('바쁘다', 33),
#  ('에메랄드', 33),
#  ('낮', 33),
#  ('동시', 33),
#  ('놓이다', 33),
#  ('뒤바뀌다', 33),
#  ('다르다', 32),
#  ('입구', 32),
#  ('식기', 32),
#  ('파티', 32),
#  ('집중', 32),
#  ('마무리', 32),
#  ('플레이스', 32),
#  ('관광', 31),
#  ('음악', 31),
#  ('조용히', 31),
#  ('동반', 31),
#  ('시작', 31),
#  ('확인', 31),
#  ('독채펜션', 31),
#  ('무료', 31),
#  ('한옥스테', 30),
#  ('리모델링', 30),
#  ('새롭다', 30),
#  ('코스', 30),
#  ('이름', 29),
#  ('옛', 29),
#  ('불편', 29),
#  ('구름', 29),
#  ('돌', 29),
#  ('밭', 29),
#  ('비치', 29),
#  ('잔잔', 29),
#  ('독채숙소', 29),
#  ('돋보이다', 29),
#  ('글램', 29),
#  ('낭만', 29),
#  ('루프', 29),
#  ('읽다', 28),
#  ('오후', 28),
#  ('잔', 28),
#  ('루프탑', 28),
#  ('공용', 28),
#  ('우', 28),
#  ('통유리', 28),
#  ('소', 28),
#  ('다락방', 28),
#  ('글램핑', 28),
#  ('탄생', 28),
#  ('제주도독채', 28),
#  ('걷다', 27),
#  ('품다', 27),
#  ('통창', 27),
#  ('충청북도', 27),
#  ('충북', 27),
#  ('겨울', 27),
#  ('어메니티', 27),
#  ('물들다', 27),
#  ('뜨다', 27),
#  ('날씨', 27),
#  ('마주', 27),
#  ('호스트', 27),
#  ('서로', 27),
#  ('밤하늘', 27),
#  ('필요', 27),
#  ('저녁', 26),
#  ('전용', 26),
#  ('한가', 26),
#  ('형태', 26),
#  ('외관', 26),
#  ('담', 26),
#  ('마운틴뷰', 26),
#  ('존', 26),
#  ('애견', 26),
#  ('호수', 26),
#  ('휴가', 26),
#  ('에디터', 26),
#  ('따로', 25),
#  ('편리', 25),
#  ('류', 25),
#  ('아래', 25),
#  ('촌', 25),
#  ('한눈', 25),
#  ('르', 25),
#  ('쌓다', 24),
#  ('고급', 24),
#  ('도보', 24),
#  ('섬', 24),
#  ('특징', 24),
#  ('사이', 24),
#  ('멋', 24),
#  ('불', 24),
#  ('바닷가', 23),
#  ('기억', 23),
#  ('완산구', 23),
#  ('오래', 23),
#  ('편의', 23),
#  ('동네', 23),
#  ('독특', 23),
#  ('식', 23),
#  ('충분', 23),
#  ('무', 23),
#  ('뚫리다', 23),
#  ('센스', 23),
#  ('뛰어놀다', 23),
#  ('귀엽다', 23),
#  ('바뀌다', 23),
#  ('방해', 23),
#  ('불가', 22),
#  ('동남아', 22),
#  ('신축', 22),
#  ('부엌', 22),
#  ('기본', 22),
#  ('봄', 22),
#  ('귤', 22),
#  ('경주독채', 22),
#  ('웰컴', 22),
#  ('입시', 22),
#  ('티', 21),
#  ('제대로', 21),
#  ('주차장', 21),
#  ('아름다움', 21),
#  ('년대', 21),
#  ('경험', 21),
#  ('종류', 21),
#  ('흘러가다', 21),
#  ('올라가다', 21),
#  ('뻥', 21),
#  ('내내', 21),
#  ('맛있다', 21),
#  ('둘러싸이다', 21),
#  ('포레스트', 21),
#  ('안채', 21),
#  ('미', 21),
#  ('흐르다', 21),
#  ('색감', 21),
#  ('맞추다', 21),
#  ('야경', 21),
#  ('햇빛', 20),
#  ('살리다', 20),
#  ('미니', 20),
#  ('원룸', 20),
#  ('온', 20),
#  ('디자인', 20),
#  ('부족', 20),
#  ('끼리', 20),
#  ('벌다', 20),
#  ('프로젝트', 20),
#  ('푸릇푸릇', 20),
#  ('대나무', 20),
#  ('천', 20),
#  ('즈', 20),
#  ('은은', 19),
#  ('접근', 19),
#  ('선택', 19),
#  ('종로', 19),
#  ('끝', 19),
#  ('순간', 19),
#  ('원하다', 19),
#  ('수풀', 19),
#  ('라운드', 19),
#  ('머금다', 19),
#  ('도구', 18),
#  ('지루', 18),
#  ('맑다', 18),
#  ('멀리', 18),
#  ('전주한옥마을', 18),
#  ('도시', 18),
#  ('구경', 18),
#  ('독립', 18),
#  ('다이닝룸', 18),
#  ('하나하나', 18),
#  ('특히', 18),
#  ('아담', 18),
#  ('오름', 18),
#  ('계단', 18),
#  ('이어지다', 18),
#  ('별채', 18),
#  ('현재', 18),
#  ('진행', 18),
#  ('미학', 18),
#  ('낮다', 18),
#  ('푸르르다', 18),
#  ('전망', 18),
#  ('휴양지', 18),
#  ('느리다', 18),
#  ('너머', 18),
#  ('마루', 18),
#  ('반기다', 18),
#  ('부부', 17),
#  ('정취', 17),
#  ('라운지', 17),
#  ('연결', 17),
#  ('골목', 17),
#  ('간직', 17),
#  ('대여', 17),
#  ('반신', 17),
#  ('하이라이트', 17),
#  ('얻다', 17),
#  ('편의점', 17),
#  ('신혼여행', 17),
#  ('인기', 17),
#  ('히노끼탕', 17),
#  ('멍', 17),
#  ('요기', 17),
#  ('가까이', 16),
#  ('머신', 16),
#  ('갤러리', 16),
#  ('소박', 16),
#  ('세', 16),
#  ('멀다', 16),
#  ('넘치다', 16),
#  ('즐겁다', 16),
#  ('충분히', 16),
#  ('향기', 16),
#  ('복층', 16),
#  ('산책로', 16),
#  ('자세', 16),
#  ('제주특별자치도', 16),
#  ('재미', 16),
#  ('자유', 16),
#  ('애', 16),
#  ('제외', 16),
#  ('컨셉', 16),
#  ('세트', 16),
#  ('기장', 16),
#  ('소나무', 16),
#  ('풀벌레', 16),
#  ('오션', 16),
#  ('고스란', 16),
#  ('글', 16),
#  ('다락', 16),
#  ('곡', 15),
#  ('크기', 15),
#  ('명소', 15),
#  ('촬영', 15),
#  ('시골집', 15),
#  ('스타일', 15),
#  ('최근', 15),
#  ('느긋', 15),
#  ('새', 15),
#  ('나가다', 15),
#  ('화이트톤', 15),
#  ('의자', 15),
#  ('편백', 15),
#  ('규모', 15),
#  ('좋아하다', 15),
#  ('타입', 15),
#  ('요금', 15),
#  ('용품', 15),
#  ('코', 15),
#  ('툇마루', 15),
#  ('면', 15),
#  ('텐트', 15),
#  ('틈', 15),
#  ('어느새', 15),
#  ('사이트', 15),
#  ('파', 15),
#  ('파크', 15),
#  ('블루', 15),
#  ('올', 15),
#  ('분리', 14),
#  ('차분', 14),
#  ('어울리다', 14),
#  ('보존', 14),
#  ('갯벌', 14),
#  ('트다', 14),
#  ('드넓다', 14),
#  ('치다', 14),
#  ('주택가', 14),
#  ('개조', 14),
#  ('턴테이블', 14),
#  ('넷플릭스', 14),
#  ('생활', 14),
#  ('서비스', 14),
#  ('치', 14),
#  ('비용', 14),
#  ('굽다', 14),
#  ('오붓', 14),
#  ('개인', 14),
#  ('깊다', 14),
#  ('포함', 14),
#  ('클럽', 14),
#  ('커다랗다', 14),
#  ('반려', 14),
#  ('자랑', 14),
#  ('조합', 14),
#  ('코로나', 14),
#  ('산속', 14),
#  ('색다르다', 14),
#  ('캠프', 14),
#  ('가든', 14),
#  ('초반', 14),
#  ('맞이', 13),
#  ('주차', 13),
#  ('기존', 13),
#  ('개방', 13),
#  ('평상', 13),
#  ('이루다', 13),
#  ('프리미엄', 13),
#  ('데크', 13),
#  ('설치', 13),
#  ('뒷마당', 13),
#  ('쇼파', 13),
#  ('성인', 13),
#  ('깨끗', 13),
#  ('완료', 13),
#  ('종로구', 13),
#  ('옥상', 13),
#  ('침구', 13),
#  ('무드', 13),
#  ('여러', 13),
#  ('브런치', 13),
#  ('놀이', 13),
#  ('드', 13),
#  ('단어', 13),
#  ('독채풀', 13),
#  ('설레다', 13),
#  ('불멍', 13),
#  ('내려놓다', 13),
#  ('떨어지다', 13),
#  ('솜', 13),
#  ('홈', 13),
#  ('호캉스', 13),
#  ('일기', 13),
#  ('안목', 13),
#  ('재료', 12),
#  ('정확', 12),
#  ('컬러', 12),
#  ('오두막', 12),
#  ('대형', 12),
#  ('마트', 12),
#  ('식당', 12),
#  ('배치', 12),
#  ('씩', 12),
#  ('조', 12),
#  ('유지', 12),
#  ('자체', 12),
#  ('식탁', 12),
#  ('메뉴', 12),
#  ('서재', 12),
#  ('싱그럽다', 12),
#  ('구옥', 12),
#  ('와인', 12),
#  ('빛나다', 12),
#  ('황토', 12),
#  ('야자수', 12),
#  ('입욕', 12),
#  ('최고', 12),
#  ('락', 12),
#  ('천천히', 12),
#  ('강아지', 12),
#  ('투숙객', 12),
#  ('음료', 12),
#  ('그리다', 12),
#  ('프라이빗함', 12),
#  ('숙', 12),
#  ('테마', 12),
#  ('한국', 12),
#  ('피톤치드', 12),
#  ('아웃', 12),
#  ('서해', 11),
#  ('지붕', 11),
#  ('세련', 11),
#  ('프로젝터', 11),
#  ('잊다', 11),
#  ('댁', 11),
#  ('변하다', 11),
#  ('뒤', 11),
#  ('앤', 11),
#  ('여느', 11),
#  ('서까래', 11),
#  ('객리단길', 11),
#  ('모이다', 11),
#  ('의미', 11),
#  ('바구니', 11),
#  ('건축', 11),
#  ('바비큐', 11),
#  ('함', 11),
#  ('맥주', 11),
#  ('들어서다', 11),
#  ('동물', 11),
#  ('이스케이프', 11),
#  ('공원', 11),
#  ('본채', 11),
#  ('끼다', 11),
#  ('물품', 11),
#  ('온실', 11),
#  ('이색', 11),
#  ('훌쩍', 11),
#  ('고택', 11),
#  ('몰디브', 11),
#  ('벚꽃', 11),
#  ('타임', 11),
#  ('맨션', 11),
#  ('어렵다', 10),
#  ('베이지', 10),
#  ('잠', 10),
#  ('캡슐', 10),
#  ('여행객', 10),
#  ('쪽', 10),
#  ('소담', 10),
#  ('북스테', 10),
#  ('지니다', 10),
#  ('중심', 10),
#  ('주스', 10),
#  ('바', 10),
#  ('그네', 10),
#  ('그릴', 10),
#  ('하얗다', 10),
#  ('메인', 10),
#  ('마감', 10),
#  ('플레이', 10),
#  ('빠지다', 10),
#  ('네이버', 10),
#  ('풀리다', 10),
#  ('바깥', 10),
#  ('가운데', 10),
#  ('기장군', 10),
#  ('부산광역시', 10),
#  ('삶', 10),
#  ('시즌', 10),
#  ('덕분', 10),
#  ('지나다', 10),
#  ('내리쬐다', 10),
#  ('브', 10),
#  ('챙기다', 10),
#  ('떠오르다', 10),
#  ('울주', 10),
#  ('앞마당', 10),
#  ('전포동', 10),
#  ('리버뷰', 10),
#  ('비밀', 10),
#  ('자아내다', 10),
#  ('바깥채', 10),
#  ('움', 10),
#  ('해안로', 10),
#  ('온도', 10),
#  ('인터뷰', 10),
#  ('연남동', 10),
#  ('짝꿍', 10),
#  ('온화', 10),
#  ('해외여행', 9),
#  ('한라산', 9),
#  ('일어나다', 9),
#  ('스며들다', 9),
#  ('할머니', 9),
#  ('첨성대', 9),
#  ('볼거리', 9),
#  ('복잡', 9),
#  ('흔적', 9),
#  ('낮잠', 9),
#  ('너무나', 9),
#  ('샌드위치', 9),
#  ('과일', 9),
#  ('시내', 9),
#  ('차경', 9),
#  ('따다', 9),
#  ('과수원', 9),
#  ('알리다', 9),
#  ('제니', 9),
#  ('바래다', 9),
#  ('접근성', 9),
#  ('귤밭', 9),
#  ('켜다', 9),
#  ('파랗다', 9),
#  ('리틀', 9),
#  ('단위', 9),
#  ('섬세', 9),
#  ('손길', 9),
#  ('잔디밭', 9),
#  ('해먹다', 9),
#  ('사이즈', 9),
#  ('전주독채', 9),
#  ('맞닿다', 9),
#  ('여름휴가', 9),
#  ('날짜', 9),
#  ('편지', 9),
#  ('구분', 9),
#  ('섬진강', 9),
#  ('포토', 9),
#  ('셔', 9),
#  ('제주스테', 9),
#  ('원목', 9),
#  ('낚시', 9),
#  ('북한강', 9),
#  ('폭', 9),
#  ('눈부시다', 9),
#  ('사색', 9),
#  ('신선', 9),
#  ('모티브', 9),
#  ('신혼', 9),
#  ('웨이', 9),
#  ('아일랜드', 9),
#  ('지리산', 9),
#  ('담그다', 9),
#  ('더블', 9),
#  ('컨디션', 9),
#  ('요즘', 9),
#  ('종일', 9),
#  ('울다', 9),
#  ('연못', 9),
#  ('뿜다', 9),
#  ('저장', 9),
#  ('뷰맛집', 9),
#  ('쉽다', 8),
#  ('걱정', 8),
#  ('이내', 8),
#  ('만족', 8),
#  ('로맨틱', 8),
#  ('터', 8),
#  ('특유', 8),
#  ('디저트', 8),
#  ('내음', 8),
#  ('갈다', 8),
#  ('답답', 8),
#  ('즐거움', 8),
#  ('비추다', 8),
#  ('표시', 8),
#  ('발뮤', 8),
#  ('위로', 8),
#  ('바닥', 8),
#  ('자전거', 8),
#  ('시장', 8),
#  ('시끄럽다', 8),
#  ('전경', 8),
#  ('서초', 8),
#  ('온기', 8),
#  ('감귤', 8),
#  ('맛보다', 8),
#  ('웨이브', 8),
#  ('안노이', 8),
#  ('심플', 8),
#  ('미니멀', 8),
#  ('스위트룸', 8),
#  ('뿐', 8),
#  ('해돋이', 8),
#  ('올리브', 8),
#  ('냉장고', 8),
#  ('브라운', 8),
#  ('전라도', 8),
#  ('켠', 8),
#  ('온돌방', 8),
#  ('패밀리', 8),
#  ('우유', 8),
#  ('간식', 8),
#  ('아기', 8),
#  ('일본', 8),
#  ('모포', 8),
#  ('평수', 8),
#  ('희다', 8),
#  ('고유', 8),
#  ('경관', 8),
#  ('최대한', 8),
#  ('포항오션뷰', 8),
#  ('장점', 8),
#  ('유료', 8),
#  ('벽난로', 8),
#  ('변화', 8),
#  ('액자', 8),
#  ('파우더', 8),
#  ('알록달록', 8),
#  ('인근', 8),
#  ('거제남서', 8),
#  ('꿈꾸다', 8),
#  ('레', 8),
#  ('빌리다', 8),
#  ('아치', 8),
#  ('벽', 8),
#  ('히노끼', 8),
#  ('뷰맛', 8),
#  ('객', 8),
#  ('장작', 8),
#  ('카라반', 8),
#  ('건축가', 8),
#  ('고요함', 8),
#  ('듬뿍', 8),
#  ('완비', 8),
#  ('쇼', 8),
#  ('바다뷰', 8),
#  ('넉넉', 8),
#  ('캐나다', 8),
#  ('적절', 8),
#  ('예술', 8),
#  ('배우다', 8),
#  ('슈가브리', 8),
#  ('제주핫', 8),
#  ('월미도', 8),
#  ('유유', 8),
#  ('오늘', 8),
#  ('로컬', 8),
#  ('힘들다', 7),
#  ('지역', 7),
#  ('숨다', 7),
#  ('독채스테', 7),
#  ('화려', 7),
#  ('술', 7),
#  ('선사', 7),
#  ('들리다', 7),
#  ('토스터', 7),
#  ('별도', 7),
#  ('링', 7),
#  ('게임', 7),
#  ('견', 7),
#  ('모래', 7),
#  ('에어', 7),
#  ('시청', 7),
#  ('메이킷슬로', 7),
#  ('멈추다', 7),
#  ('감동', 7),
#  ('센터', 7),
#  ('내려다보이다', 7),
#  ('텃밭', 7),
#  ('금액', 7),
#  ('라이프', 7),
#  ('놀이터', 7),
#  ('수수료', 7),
#  ('송정해수욕장', 7),
#  ('동경', 7),
#  ('나름', 7),
#  ('이솝', 7),
#  ('녹이다', 7),
#  ('족욕', 7),
#  ('격', 7),
#  ('골', 7),
#  ('확정', 7),
#  ('느릿', 7),
#  ('그랜드', 7),
#  ('최', 7),
#  ('드링크', 7),
#  ('피다', 7),
#  ('색', 7),
#  ('화우', 7),
#  ('스토리', 7),
#  ('거제독채', 7),
#  ('구역', 7),
#  ('르컬렉티', 7),
#  ('보유', 7),
#  ('유유자적', 7),
#  ('한옥스테이', 7),
#  ('두바이', 7),
#  ('레트로', 7),
#  ('새하얗다', 7),
#  ('지나가다', 7),
#  ('포항독채', 7),
#  ('가조도', 7),
#  ('탄', 7),
#  ('폭포', 7),
#  ('주의', 7),
#  ('숲속', 7),
#  ('연가', 7),
#  ('라이트', 7),
#  ('버블', 7),
#  ('숲뷰', 7),
#  ('이탈리아', 7),
#  ('모양', 7),
#  ('트리하우스', 7),
#  ('타일', 7),
#  ('감탄', 7),
#  ('순수', 7),
#  ('여관', 7),
#  ('파리', 7),
#  ('생기다', 7),
#  ('성비', 7),
#  ('만하다', 7),
#  ('적정', 7),
#  ('형제', 7),
#  ('초목', 7),
#  ('오션뷰숙소', 7),
#  ('각이쟈', 7),
#  ('제주오션뷰', 7),
#  ('제제', 7),
#  ('카루나', 7),
#  ('유숙', 7),
#  ('다이슨', 7),
#  ('투명', 7),
#  ('스톤', 6),
#  ('유리창', 6),
#  ('고등어', 6),
#  ('완성', 6),
#  ('인연', 6),
#  ('포석로', 6),
#  ('고스', 6),
#  ('불다', 6),
#  ('파노라마', 6),
#  ('조망', 6),
#  ('담장', 6),
#  ('모해', 6),
#  ('짐', 6),
#  ('기와', 6),
#  ('지저귀다', 6),
#  ('돌아가다', 6),
#  ('문자', 6),
#  ('정갈', 6),
#  ('불리다', 6),
#  ('하조', 6),
#  ('전망대', 6),
#  ('유튜브', 6),
#  ('영도구', 6),
#  ('해석', 6),
#  ('배달', 6),
#  ('청결', 6),
#  ('스페인', 6),
#  ('일반', 6),
#  ('풍차', 6),
#  ('선선', 6),
#  ('층고', 6),
#  ('협재해수욕장', 6),
#  ('제품', 6),
#  ('바베큐장', 6),
#  ('마운틴', 6),
#  ('복도', 6),
#  ('양념', 6),
#  ('슬로우', 6),
#  ('여백', 6),
#  ('스위치', 6),
#  ('이후', 6),
#  ('덜다', 6),
#  ('미끄럼틀', 6),
#  ('경상도', 6),
#  ('로망', 6),
#  ('체', 6),
#  ('콘크리트', 6),
#  ('퀸', 6),
#  ('시간대', 6),
#  ('어둡다', 6),
#  ('베이다', 6),
#  ('닿다', 6),
#  ('아파트', 6),
#  ('푹신', 6),
#  ('방식', 6),
#  ('시리얼', 6),
#  ('농장', 6),
#  ('가꾸다', 6),
#  ('휴휴', 6),
#  ('열리다', 6),
#  ('잇다', 6),
#  ('소설', 6),
#  ('용산구', 6),
#  ('동해안로', 6),
#  ('공유', 6),
#  ('형식', 6),
#  ('상관없이', 6),
#  ('전주한옥스테', 6),
#  ('다채', 6),
#  ('수놓다', 6),
#  ('도어', 6),
#  ('웨스트포트', 6),
#  ('스탠다드', 6),
#  ('노곤', 6),
#  ('일정', 6),
#  ('안성맞춤', 6),
#  ('지키다', 6),
#  ('웰컴티', 6),
#  ('흘러나오다', 6),
#  ('그레이', 6),
#  ('논밭', 6),
#  ('홀리다', 6),
#  ('이태원', 6),
#  ('알맞다', 6),
#  ('숨기다', 6),
#  ('마주치다', 6),
#  ('치즈', 6),
#  ('다이닝', 6),
#  ...]

# %%
keywords = sorted(a.items(), key=lambda x : x[1], reverse = True)

# %%
keywords # 바다, 한옥, 힐링, 수영장, 카페, 따뜻, 마을, 조용, 오션뷰, 바베큐, 풍경, 독채, 스파, 자쿠지, 돌담
# Out:
# [('바다', 369),
#  ('한옥', 355),
#  ('힐링', 283),
#  ('수영장', 274),
#  ('비수기', 273),
#  ('바라보다', 264),
#  ('가득', 261),
#  ('가족', 234),
#  ('인테리어', 208),
#  ('카페', 205),
#  ('넓다', 203),
#  ('따뜻', 199),
#  ('마을', 198),
#  ('조용', 195),
#  ('국내', 195),
#  ('침실', 188),
#  ('보내다', 184),
#  ('오션뷰', 184),
#  ('데일리', 176),
#  ('바베큐', 175),
#  ('계획', 175),
#  ('예쁘다', 174),
#  ('분위기', 173),
#  ('아름답다', 173),
#  ('거실', 173),
#  ('호캉', 173),
#  ('하루', 165),
#  ('매력', 165),
#  ('풍경', 163),
#  ('여유', 160),
#  ('경남', 159),
#  ('마음', 155),
#  ('야외', 155),
#  ('기록', 155),
#  ('휴식', 154),
#  ('편안', 153),
#  ('꾸미다', 150),
#  ('조식', 150),
#  ('여행지', 150),
#  ('아늑', 149),
#  ('마당', 145),
#  ('이쁘다', 142),
#  ('탕', 137),
#  ('햇살', 137),
#  ('숲', 136),
#  ('소리', 135),
#  ('소품', 133),
#  ('다양', 132),
#  ('갖추다', 132),
#  ('깔끔', 129),
#  ('하늘', 128),
#  ('정원', 127),
#  ('사용', 123),
#  ('담다', 123),
#  ('커플', 122),
#  ('문', 121),
#  ('프라이빗', 118),
#  ('테라스', 118),
#  ('누리다', 118),
#  ('주변', 115),
#  ('친구', 115),
#  ('거리', 114),
#  ('독채', 110),
#  ('경상북도', 107),
#  ('주인장', 107),
#  ('추억', 106),
#  ('오롯', 106),
#  ('바람', 103),
#  ('노을', 102),
#  ('쉬다', 102),
#  ('나누다', 102),
#  ('밤', 101),
#  ('화이트', 101),
#  ('트이다', 101),
#  ('핫', 101),
#  ('개별', 99),
#  ('아기자기', 98),
#  ('운영', 97),
#  ('총', 97),
#  ('나무', 96),
#  ('민박', 95),
#  ('스파', 95),
#  ('제주독채', 94),
#  ('연인', 93),
#  ('이야기', 88),
#  ('프다', 87),
#  ('톤', 86),
#  ('욕조', 86),
#  ('곳곳', 86),
#  ('선물', 86),
#  ('만끽', 85),
#  ('산', 85),
#  ('히', 82),
#  ('모든', 81),
#  ('일상', 80),
#  ('들어오다', 80),
#  ('앉다', 80),
#  ('없이', 77),
#  ('커피', 77),
#  ('스럽', 75),
#  ('이루어지다', 75),
#  ('계절', 75),
#  ('쌓이다', 75),
#  ('피로', 75),
#  ('전체', 74),
#  ('그대로', 74),
#  ('만나다', 74),
#  ('취하다', 72),
#  ('밖', 72),
#  ('포근', 72),
#  ('머무르다', 72),
#  ('푸르다', 71),
#  ('실내', 69),
#  ('벗어나다', 69),
#  ('자쿠지', 69),
#  ('고르다', 69),
#  ('배경', 68),
#  ('흐름', 68),
#  ('팀', 67),
#  ('산책', 66),
#  ('시설', 66),
#  ('시골', 66),
#  ('두르다', 66),
#  ('멋지다', 65),
#  ('인생', 64),
#  ('리', 63),
#  ('욕실', 63),
#  ('맞다', 63),
#  ('더욱', 63),
#  ('일출', 63),
#  ('자리', 62),
#  ('동쪽', 62),
#  ('한적', 62),
#  ('해변', 62),
#  ('어우러지다', 62),
#  ('쉼', 62),
#  ('펼쳐지다', 61),
#  ('서쪽', 61),
#  ('제작', 61),
#  ('들어가다', 61),
#  ('취향', 61),
#  ('확', 61),
#  ('감상', 60),
#  ('돌담', 60),
#  ('침대', 59),
#  ('책', 59),
#  ('온전', 59),
#  ('물놀이', 59),
#  ('아침', 58),
#  ('전라남도', 58),
#  ('따스', 58),
#  ('그림', 58),
#  ('프라이', 57),
#  ('가깝다', 57),
#  ('근처', 56),
#  ('새소리', 56),
#  ('형', 55),
#  ('나뉘다', 55),
#  ('창문', 55),
#  ('태그해', 55),
#  ('콘탠츠', 55),
#  ('해수욕장', 54),
#  ('실', 54),
#  ('담기다', 54),
#  ('우드', 54),
#  ('여름', 54),
#  ('빛', 53),
#  ('눈', 53),
#  ('빗', 53),
#  ('우드톤', 53),
#  ('껏', 52),
#  ('피크닉', 51),
#  ('고즈넉', 51),
#  ('듣다', 50),
#  ('인피니티', 50),
#  ('참고', 49),
#  ('이국', 49),
#  ('관광지', 49),
#  ('특별', 49),
#  ('짓다', 49),
#  ('구조', 49),
#  ('모습', 49),
#  ('기분', 48),
#  ('감각', 48),
#  ('머물다', 48),
#  ('건물', 47),
#  ('놀다', 47),
#  ('편하다', 46),
#  ('잔디', 46),
#  ('테이블', 45),
#  ('사계절', 44),
#  ('조명', 44),
#  ('샷', 44),
#  ('높다', 43),
#  ('유명', 43),
#  ('잡다', 42),
#  ('지치다', 42),
#  ('포인트', 42),
#  ('꽃', 41),
#  ('배려', 41),
#  ('눕다', 40),
#  ('시원', 40),
#  ('쏟아지다', 40),
#  ('몸', 40),
#  ('풀장', 40),
#  ('그램', 40),
#  ('국내외', 40),
#  ('채우다', 39),
#  ('모던', 39),
#  ('유럽', 39),
#  ('아름', 39),
#  ('정성', 39),
#  ('바라다', 38),
#  ('키즈', 38),
#  ('해외', 38),
#  ('취사', 36),
#  ('간단', 36),
#  ('빔프로젝터', 36),
#  ('체험', 36),
#  ('완벽', 36),
#  ('식물', 36),
#  ('포토존', 36),
#  ('물씬', 36),
#  ('별장', 36),
#  ('단독', 35),
#  ('일몰', 35),
#  ('뜻', 35),
#  ('먼저', 35),
#  ('현대', 34),
#  ('데이트', 34),
#  ('탁', 34),
#  ('주택', 33),
#  ('언덕', 33),
#  ('전통', 33),
#  ('가만히', 33),
#  ('빈티지', 33),
#  ('바쁘다', 33),
#  ('에메랄드', 33),
#  ('낮', 33),
#  ('동시', 33),
#  ('놓이다', 33),
#  ('뒤바뀌다', 33),
#  ('다르다', 32),
#  ('입구', 32),
#  ('식기', 32),
#  ('파티', 32),
#  ('집중', 32),
#  ('마무리', 32),
#  ('플레이스', 32),
#  ('관광', 31),
#  ('음악', 31),
#  ('조용히', 31),
#  ('동반', 31),
#  ('시작', 31),
#  ('확인', 31),
#  ('독채펜션', 31),
#  ('무료', 31),
#  ('한옥스테', 30),
#  ('리모델링', 30),
#  ('새롭다', 30),
#  ('코스', 30),
#  ('이름', 29),
#  ('옛', 29),
#  ('불편', 29),
#  ('구름', 29),
#  ('돌', 29),
#  ('밭', 29),
#  ('비치', 29),
#  ('잔잔', 29),
#  ('독채숙소', 29),
#  ('돋보이다', 29),
#  ('글램', 29),
#  ('낭만', 29),
#  ('루프', 29),
#  ('읽다', 28),
#  ('오후', 28),
#  ('잔', 28),
#  ('루프탑', 28),
#  ('공용', 28),
#  ('우', 28),
#  ('통유리', 28),
#  ('소', 28),
#  ('다락방', 28),
#  ('글램핑', 28),
#  ('탄생', 28),
#  ('제주도독채', 28),
#  ('걷다', 27),
#  ('품다', 27),
#  ('통창', 27),
#  ('충청북도', 27),
#  ('충북', 27),
#  ('겨울', 27),
#  ('어메니티', 27),
#  ('물들다', 27),
#  ('뜨다', 27),
#  ('날씨', 27),
#  ('마주', 27),
#  ('호스트', 27),
#  ('서로', 27),
#  ('밤하늘', 27),
#  ('필요', 27),
#  ('저녁', 26),
#  ('전용', 26),
#  ('한가', 26),
#  ('형태', 26),
#  ('외관', 26),
#  ('담', 26),
#  ('마운틴뷰', 26),
#  ('존', 26),
#  ('애견', 26),
#  ('호수', 26),
#  ('휴가', 26),
#  ('에디터', 26),
#  ('따로', 25),
#  ('편리', 25),
#  ('류', 25),
#  ('아래', 25),
#  ('촌', 25),
#  ('한눈', 25),
#  ('르', 25),
#  ('쌓다', 24),
#  ('고급', 24),
#  ('도보', 24),
#  ('섬', 24),
#  ('특징', 24),
#  ('사이', 24),
#  ('멋', 24),
#  ('불', 24),
#  ('바닷가', 23),
#  ('기억', 23),
#  ('완산구', 23),
#  ('오래', 23),
#  ('편의', 23),
#  ('동네', 23),
#  ('독특', 23),
#  ('식', 23),
#  ('충분', 23),
#  ('무', 23),
#  ('뚫리다', 23),
#  ('센스', 23),
#  ('뛰어놀다', 23),
#  ('귀엽다', 23),
#  ('바뀌다', 23),
#  ('방해', 23),
#  ('불가', 22),
#  ('동남아', 22),
#  ('신축', 22),
#  ('부엌', 22),
#  ('기본', 22),
#  ('봄', 22),
#  ('귤', 22),
#  ('경주독채', 22),
#  ('웰컴', 22),
#  ('입시', 22),
#  ('티', 21),
#  ('제대로', 21),
#  ('주차장', 21),
#  ('아름다움', 21),
#  ('년대', 21),
#  ('경험', 21),
#  ('종류', 21),
#  ('흘러가다', 21),
#  ('올라가다', 21),
#  ('뻥', 21),
#  ('내내', 21),
#  ('맛있다', 21),
#  ('둘러싸이다', 21),
#  ('포레스트', 21),
#  ('안채', 21),
#  ('미', 21),
#  ('흐르다', 21),
#  ('색감', 21),
#  ('맞추다', 21),
#  ('야경', 21),
#  ('햇빛', 20),
#  ('살리다', 20),
#  ('미니', 20),
#  ('원룸', 20),
#  ('온', 20),
#  ('디자인', 20),
#  ('부족', 20),
#  ('끼리', 20),
#  ('벌다', 20),
#  ('프로젝트', 20),
#  ('푸릇푸릇', 20),
#  ('대나무', 20),
#  ('천', 20),
#  ('즈', 20),
#  ('은은', 19),
#  ('접근', 19),
#  ('선택', 19),
#  ('종로', 19),
#  ('끝', 19),
#  ('순간', 19),
#  ('원하다', 19),
#  ('수풀', 19),
#  ('라운드', 19),
#  ('머금다', 19),
#  ('도구', 18),
#  ('지루', 18),
#  ('맑다', 18),
#  ('멀리', 18),
#  ('전주한옥마을', 18),
#  ('도시', 18),
#  ('구경', 18),
#  ('독립', 18),
#  ('다이닝룸', 18),
#  ('하나하나', 18),
#  ('특히', 18),
#  ('아담', 18),
#  ('오름', 18),
#  ('계단', 18),
#  ('이어지다', 18),
#  ('별채', 18),
#  ('현재', 18),
#  ('진행', 18),
#  ('미학', 18),
#  ('낮다', 18),
#  ('푸르르다', 18),
#  ('전망', 18),
#  ('휴양지', 18),
#  ('느리다', 18),
#  ('너머', 18),
#  ('마루', 18),
#  ('반기다', 18),
#  ('부부', 17),
#  ('정취', 17),
#  ('라운지', 17),
#  ('연결', 17),
#  ('골목', 17),
#  ('간직', 17),
#  ('대여', 17),
#  ('반신', 17),
#  ('하이라이트', 17),
#  ('얻다', 17),
#  ('편의점', 17),
#  ('신혼여행', 17),
#  ('인기', 17),
#  ('히노끼탕', 17),
#  ('멍', 17),
#  ('요기', 17),
#  ('가까이', 16),
#  ('머신', 16),
#  ('갤러리', 16),
#  ('소박', 16),
#  ('세', 16),
#  ('멀다', 16),
#  ('넘치다', 16),
#  ('즐겁다', 16),
#  ('충분히', 16),
#  ('향기', 16),
#  ('복층', 16),
#  ('산책로', 16),
#  ('자세', 16),
#  ('제주특별자치도', 16),
#  ('재미', 16),
#  ('자유', 16),
#  ('애', 16),
#  ('제외', 16),
#  ('컨셉', 16),
#  ('세트', 16),
#  ('기장', 16),
#  ('소나무', 16),
#  ('풀벌레', 16),
#  ('오션', 16),
#  ('고스란', 16),
#  ('글', 16),
#  ('다락', 16),
#  ('곡', 15),
#  ('크기', 15),
#  ('명소', 15),
#  ('촬영', 15),
#  ('시골집', 15),
#  ('스타일', 15),
#  ('최근', 15),
#  ('느긋', 15),
#  ('새', 15),
#  ('나가다', 15),
#  ('화이트톤', 15),
#  ('의자', 15),
#  ('편백', 15),
#  ('규모', 15),
#  ('좋아하다', 15),
#  ('타입', 15),
#  ('요금', 15),
#  ('용품', 15),
#  ('코', 15),
#  ('툇마루', 15),
#  ('면', 15),
#  ('텐트', 15),
#  ('틈', 15),
#  ('어느새', 15),
#  ('사이트', 15),
#  ('파', 15),
#  ('파크', 15),
#  ('블루', 15),
#  ('올', 15),
#  ('분리', 14),
#  ('차분', 14),
#  ('어울리다', 14),
#  ('보존', 14),
#  ('갯벌', 14),
#  ('트다', 14),
#  ('드넓다', 14),
#  ('치다', 14),
#  ('주택가', 14),
#  ('개조', 14),
#  ('턴테이블', 14),
#  ('넷플릭스', 14),
#  ('생활', 14),
#  ('서비스', 14),
#  ('치', 14),
#  ('비용', 14),
#  ('굽다', 14),
#  ('오붓', 14),
#  ('개인', 14),
#  ('깊다', 14),
#  ('포함', 14),
#  ('클럽', 14),
#  ('커다랗다', 14),
#  ('반려', 14),
#  ('자랑', 14),
#  ('조합', 14),
#  ('코로나', 14),
#  ('산속', 14),
#  ('색다르다', 14),
#  ('캠프', 14),
#  ('가든', 14),
#  ('초반', 14),
#  ('맞이', 13),
#  ('주차', 13),
#  ('기존', 13),
#  ('개방', 13),
#  ('평상', 13),
#  ('이루다', 13),
#  ('프리미엄', 13),
#  ('데크', 13),
#  ('설치', 13),
#  ('뒷마당', 13),
#  ('쇼파', 13),
#  ('성인', 13),
#  ('깨끗', 13),
#  ('완료', 13),
#  ('종로구', 13),
#  ('옥상', 13),
#  ('침구', 13),
#  ('무드', 13),
#  ('여러', 13),
#  ('브런치', 13),
#  ('놀이', 13),
#  ('드', 13),
#  ('단어', 13),
#  ('독채풀', 13),
#  ('설레다', 13),
#  ('불멍', 13),
#  ('내려놓다', 13),
#  ('떨어지다', 13),
#  ('솜', 13),
#  ('홈', 13),
#  ('호캉스', 13),
#  ('일기', 13),
#  ('안목', 13),
#  ('재료', 12),
#  ('정확', 12),
#  ('컬러', 12),
#  ('오두막', 12),
#  ('대형', 12),
#  ('마트', 12),
#  ('식당', 12),
#  ('배치', 12),
#  ('씩', 12),
#  ('조', 12),
#  ('유지', 12),
#  ('자체', 12),
#  ('식탁', 12),
#  ('메뉴', 12),
#  ('서재', 12),
#  ('싱그럽다', 12),
#  ('구옥', 12),
#  ('와인', 12),
#  ('빛나다', 12),
#  ('황토', 12),
#  ('야자수', 12),
#  ('입욕', 12),
#  ('최고', 12),
#  ('락', 12),
#  ('천천히', 12),
#  ('강아지', 12),
#  ('투숙객', 12),
#  ('음료', 12),
#  ('그리다', 12),
#  ('프라이빗함', 12),
#  ('숙', 12),
#  ('테마', 12),
#  ('한국', 12),
#  ('피톤치드', 12),
#  ('아웃', 12),
#  ('서해', 11),
#  ('지붕', 11),
#  ('세련', 11),
#  ('프로젝터', 11),
#  ('잊다', 11),
#  ('댁', 11),
#  ('변하다', 11),
#  ('뒤', 11),
#  ('앤', 11),
#  ('여느', 11),
#  ('서까래', 11),
#  ('객리단길', 11),
#  ('모이다', 11),
#  ('의미', 11),
#  ('바구니', 11),
#  ('건축', 11),
#  ('바비큐', 11),
#  ('함', 11),
#  ('맥주', 11),
#  ('들어서다', 11),
#  ('동물', 11),
#  ('이스케이프', 11),
#  ('공원', 11),
#  ('본채', 11),
#  ('끼다', 11),
#  ('물품', 11),
#  ('온실', 11),
#  ('이색', 11),
#  ('훌쩍', 11),
#  ('고택', 11),
#  ('몰디브', 11),
#  ('벚꽃', 11),
#  ('타임', 11),
#  ('맨션', 11),
#  ('어렵다', 10),
#  ('베이지', 10),
#  ('잠', 10),
#  ('캡슐', 10),
#  ('여행객', 10),
#  ('쪽', 10),
#  ('소담', 10),
#  ('북스테', 10),
#  ('지니다', 10),
#  ('중심', 10),
#  ('주스', 10),
#  ('바', 10),
#  ('그네', 10),
#  ('그릴', 10),
#  ('하얗다', 10),
#  ('메인', 10),
#  ('마감', 10),
#  ('플레이', 10),
#  ('빠지다', 10),
#  ('네이버', 10),
#  ('풀리다', 10),
#  ('바깥', 10),
#  ('가운데', 10),
#  ('기장군', 10),
#  ('부산광역시', 10),
#  ('삶', 10),
#  ('시즌', 10),
#  ('덕분', 10),
#  ('지나다', 10),
#  ('내리쬐다', 10),
#  ('브', 10),
#  ('챙기다', 10),
#  ('떠오르다', 10),
#  ('울주', 10),
#  ('앞마당', 10),
#  ('전포동', 10),
#  ('리버뷰', 10),
#  ('비밀', 10),
#  ('자아내다', 10),
#  ('바깥채', 10),
#  ('움', 10),
#  ('해안로', 10),
#  ('온도', 10),
#  ('인터뷰', 10),
#  ('연남동', 10),
#  ('짝꿍', 10),
#  ('온화', 10),
#  ('해외여행', 9),
#  ('한라산', 9),
#  ('일어나다', 9),
#  ('스며들다', 9),
#  ('할머니', 9),
#  ('첨성대', 9),
#  ('볼거리', 9),
#  ('복잡', 9),
#  ('흔적', 9),
#  ('낮잠', 9),
#  ('너무나', 9),
#  ('샌드위치', 9),
#  ('과일', 9),
#  ('시내', 9),
#  ('차경', 9),
#  ('따다', 9),
#  ('과수원', 9),
#  ('알리다', 9),
#  ('제니', 9),
#  ('바래다', 9),
#  ('접근성', 9),
#  ('귤밭', 9),
#  ('켜다', 9),
#  ('파랗다', 9),
#  ('리틀', 9),
#  ('단위', 9),
#  ('섬세', 9),
#  ('손길', 9),
#  ('잔디밭', 9),
#  ('해먹다', 9),
#  ('사이즈', 9),
#  ('전주독채', 9),
#  ('맞닿다', 9),
#  ('여름휴가', 9),
#  ('날짜', 9),
#  ('편지', 9),
#  ('구분', 9),
#  ('섬진강', 9),
#  ('포토', 9),
#  ('셔', 9),
#  ('제주스테', 9),
#  ('원목', 9),
#  ('낚시', 9),
#  ('북한강', 9),
#  ('폭', 9),
#  ('눈부시다', 9),
#  ('사색', 9),
#  ('신선', 9),
#  ('모티브', 9),
#  ('신혼', 9),
#  ('웨이', 9),
#  ('아일랜드', 9),
#  ('지리산', 9),
#  ('담그다', 9),
#  ('더블', 9),
#  ('컨디션', 9),
#  ('요즘', 9),
#  ('종일', 9),
#  ('울다', 9),
#  ('연못', 9),
#  ('뿜다', 9),
#  ('저장', 9),
#  ('뷰맛집', 9),
#  ('쉽다', 8),
#  ('걱정', 8),
#  ('이내', 8),
#  ('만족', 8),
#  ('로맨틱', 8),
#  ('터', 8),
#  ('특유', 8),
#  ('디저트', 8),
#  ('내음', 8),
#  ('갈다', 8),
#  ('답답', 8),
#  ('즐거움', 8),
#  ('비추다', 8),
#  ('표시', 8),
#  ('발뮤', 8),
#  ('위로', 8),
#  ('바닥', 8),
#  ('자전거', 8),
#  ('시장', 8),
#  ('시끄럽다', 8),
#  ('전경', 8),
#  ('서초', 8),
#  ('온기', 8),
#  ('감귤', 8),
#  ('맛보다', 8),
#  ('웨이브', 8),
#  ('안노이', 8),
#  ('심플', 8),
#  ('미니멀', 8),
#  ('스위트룸', 8),
#  ('뿐', 8),
#  ('해돋이', 8),
#  ('올리브', 8),
#  ('냉장고', 8),
#  ('브라운', 8),
#  ('전라도', 8),
#  ('켠', 8),
#  ('온돌방', 8),
#  ('패밀리', 8),
#  ('우유', 8),
#  ('간식', 8),
#  ('아기', 8),
#  ('일본', 8),
#  ('모포', 8),
#  ('평수', 8),
#  ('희다', 8),
#  ('고유', 8),
#  ('경관', 8),
#  ('최대한', 8),
#  ('포항오션뷰', 8),
#  ('장점', 8),
#  ('유료', 8),
#  ('벽난로', 8),
#  ('변화', 8),
#  ('액자', 8),
#  ('파우더', 8),
#  ('알록달록', 8),
#  ('인근', 8),
#  ('거제남서', 8),
#  ('꿈꾸다', 8),
#  ('레', 8),
#  ('빌리다', 8),
#  ('아치', 8),
#  ('벽', 8),
#  ('히노끼', 8),
#  ('뷰맛', 8),
#  ('객', 8),
#  ('장작', 8),
#  ('카라반', 8),
#  ('건축가', 8),
#  ('고요함', 8),
#  ('듬뿍', 8),
#  ('완비', 8),
#  ('쇼', 8),
#  ('바다뷰', 8),
#  ('넉넉', 8),
#  ('캐나다', 8),
#  ('적절', 8),
#  ('예술', 8),
#  ('배우다', 8),
#  ('슈가브리', 8),
#  ('제주핫', 8),
#  ('월미도', 8),
#  ('유유', 8),
#  ('오늘', 8),
#  ('로컬', 8),
#  ('힘들다', 7),
#  ('지역', 7),
#  ('숨다', 7),
#  ('독채스테', 7),
#  ('화려', 7),
#  ('술', 7),
#  ('선사', 7),
#  ('들리다', 7),
#  ('토스터', 7),
#  ('별도', 7),
#  ('링', 7),
#  ('게임', 7),
#  ('견', 7),
#  ('모래', 7),
#  ('에어', 7),
#  ('시청', 7),
#  ('메이킷슬로', 7),
#  ('멈추다', 7),
#  ('감동', 7),
#  ('센터', 7),
#  ('내려다보이다', 7),
#  ('텃밭', 7),
#  ('금액', 7),
#  ('라이프', 7),
#  ('놀이터', 7),
#  ('수수료', 7),
#  ('송정해수욕장', 7),
#  ('동경', 7),
#  ('나름', 7),
#  ('이솝', 7),
#  ('녹이다', 7),
#  ('족욕', 7),
#  ('격', 7),
#  ('골', 7),
#  ('확정', 7),
#  ('느릿', 7),
#  ('그랜드', 7),
#  ('최', 7),
#  ('드링크', 7),
#  ('피다', 7),
#  ('색', 7),
#  ('화우', 7),
#  ('스토리', 7),
#  ('거제독채', 7),
#  ('구역', 7),
#  ('르컬렉티', 7),
#  ('보유', 7),
#  ('유유자적', 7),
#  ('한옥스테이', 7),
#  ('두바이', 7),
#  ('레트로', 7),
#  ('새하얗다', 7),
#  ('지나가다', 7),
#  ('포항독채', 7),
#  ('가조도', 7),
#  ('탄', 7),
#  ('폭포', 7),
#  ('주의', 7),
#  ('숲속', 7),
#  ('연가', 7),
#  ('라이트', 7),
#  ('버블', 7),
#  ('숲뷰', 7),
#  ('이탈리아', 7),
#  ('모양', 7),
#  ('트리하우스', 7),
#  ('타일', 7),
#  ('감탄', 7),
#  ('순수', 7),
#  ('여관', 7),
#  ('파리', 7),
#  ('생기다', 7),
#  ('성비', 7),
#  ('만하다', 7),
#  ('적정', 7),
#  ('형제', 7),
#  ('초목', 7),
#  ('오션뷰숙소', 7),
#  ('각이쟈', 7),
#  ('제주오션뷰', 7),
#  ('제제', 7),
#  ('카루나', 7),
#  ('유숙', 7),
#  ('다이슨', 7),
#  ('투명', 7),
#  ('스톤', 6),
#  ('유리창', 6),
#  ('고등어', 6),
#  ('완성', 6),
#  ('인연', 6),
#  ('포석로', 6),
#  ('고스', 6),
#  ('불다', 6),
#  ('파노라마', 6),
#  ('조망', 6),
#  ('담장', 6),
#  ('모해', 6),
#  ('짐', 6),
#  ('기와', 6),
#  ('지저귀다', 6),
#  ('돌아가다', 6),
#  ('문자', 6),
#  ('정갈', 6),
#  ('불리다', 6),
#  ('하조', 6),
#  ('전망대', 6),
#  ('유튜브', 6),
#  ('영도구', 6),
#  ('해석', 6),
#  ('배달', 6),
#  ('청결', 6),
#  ('스페인', 6),
#  ('일반', 6),
#  ('풍차', 6),
#  ('선선', 6),
#  ('층고', 6),
#  ('협재해수욕장', 6),
#  ('제품', 6),
#  ('바베큐장', 6),
#  ('마운틴', 6),
#  ('복도', 6),
#  ('양념', 6),
#  ('슬로우', 6),
#  ('여백', 6),
#  ('스위치', 6),
#  ('이후', 6),
#  ('덜다', 6),
#  ('미끄럼틀', 6),
#  ('경상도', 6),
#  ('로망', 6),
#  ('체', 6),
#  ('콘크리트', 6),
#  ('퀸', 6),
#  ('시간대', 6),
#  ('어둡다', 6),
#  ('베이다', 6),
#  ('닿다', 6),
#  ('아파트', 6),
#  ('푹신', 6),
#  ('방식', 6),
#  ('시리얼', 6),
#  ('농장', 6),
#  ('가꾸다', 6),
#  ('휴휴', 6),
#  ('열리다', 6),
#  ('잇다', 6),
#  ('소설', 6),
#  ('용산구', 6),
#  ('동해안로', 6),
#  ('공유', 6),
#  ('형식', 6),
#  ('상관없이', 6),
#  ('전주한옥스테', 6),
#  ('다채', 6),
#  ('수놓다', 6),
#  ('도어', 6),
#  ('웨스트포트', 6),
#  ('스탠다드', 6),
#  ('노곤', 6),
#  ('일정', 6),
#  ('안성맞춤', 6),
#  ('지키다', 6),
#  ('웰컴티', 6),
#  ('흘러나오다', 6),
#  ('그레이', 6),
#  ('논밭', 6),
#  ('홀리다', 6),
#  ('이태원', 6),
#  ('알맞다', 6),
#  ('숨기다', 6),
#  ('마주치다', 6),
#  ('치즈', 6),
#  ('다이닝', 6),
#  ...]

# %%
pd.DataFrame(keywords).to_csv('keywords.csv')

# %%
sorted(a, key= lambda x : dict[x])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-45d38c0fd088> in <module>()
# ----> 1 sorted(a, key= lambda x : dict[x])
#
# <ipython-input-177-45d38c0fd088> in <lambda>(x)
# ----> 1 sorted(a, key= lambda x : dict[x])
#
# TypeError: 'type' object is not subscriptable

# %%
test.category.values().unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-675275141963> in <module>()
# ----> 1 test.category.values().unique()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
def token(docs):
    return docs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-ebd00ac20b57> in <module>()
# ----> 1 token = token()
#
# TypeError: token() missing 1 required positional argument: 'docs'

# %%
def keywords(cateogory_num):
    result_keywords = []
    for i in range(cateogory_num):
        aaa = test.content.loc[test.category == cateogory_num]
        keyword_extractor = KeywordSummarizer(tokenize = token,
        min_count=1,
        window=8,                     # cooccurrence within a sentence
        min_cooccurrence=2,
        vocab_to_idx=None,             # you can specify vocabulary to build word graph
        df=0.85,                       # PageRank damping factor
        max_iter=30,                   # PageRank maximum iteration
        verbose=False)
        keywords = keyword_extractor.summarize(aaa, topk=20)
        result_keywords.append(keywords)
        
    return result_keywords

# %%
aaa = test.content.loc[test.category == 6]

# %%
aaa
# Out:
# 9      [한가, 분위기, 한가, 한가, 로운, 이루어지다, 프라이빗, 블럭, 쏟아지다, 따...
# 11     [바람, 꽃, 갯벌, 유럽, 바람꽃, 바람, 꽃, 바닷가, 포구, 마을, 나무, 하...
# 100    [캄포, 에메랄드, 빛, 바다, 찬란, 빛나다, 남해안, 한려수도, 자리, 잡다, ...
# 101    [리버노스풀빌라, 잔잔, 흐르다, 북한강, 바라보다, 힐링, 리버노스풀, 경계선, ...
# 104    [더에스제이, 푸르다, 빛나다, 바다, 마을, 폭, 수채화, 펼쳐지다, 더에스제이,...
#                              ...
# 656    [브로딕, 아름답다, 바다, 한라산, 경관, 한눈, 바라보다, 브로딕제, 물씬, 담...
# 657    [인터뷰, 여유, 인터뷰, 바다, 유명, 숲, 조용, 한가, 힐링, 매력, 우드톤,...
# 659    [에메랄드, 빛, 해변, 아름, 루프탑, 카페, 운영, 공용, 포함, 두채, 갖추다...
# 677    [포레스트뷰, 감상, 힐링, 스파, 비수기, 다양, 컨셉, 배경, 빈티지, 인테리어...
# 689    [마을, 하조, 해변, 이야기, 아담, 따뜻, 일본, 낭낭, 친구, 연인, 가족, ...
# Name: content, Length: 167, dtype: object

# %%
keyword_extractor = KeywordSummarizer(tokenize = token,
    min_count=1,
    window=8,                     # cooccurrence within a sentence
    min_cooccurrence=2,
    vocab_to_idx=None,             # you can specify vocabulary to build word graph
    df=0.85,                       # PageRank damping factor
    max_iter=30,                   # PageRank maximum iteration
    verbose=False)
keywords0 = keyword_extractor.summarize(aaa, topk=20)

# %%
keywords = []
keywords.append(keywords0)
keywords.append(keywords1)
keywords.append(keywords2)
keywords.append(keywords3)
keywords.append(keywords4)
keywords.append(keywords5)
keywords.append(keywords6)
keywords.append(keywords7)
keywords.append(keywords8)
keywords.append(keywords9)

# %%
pd.DataFrame(keywords).to_csv('./category_keywords.csv')

# %%
# 0 = '혼자만의 숙소' 2 = '데이트하기 좋은 숙소' 3 = '특별한 체험이 있는 숙소' 4 = '고즈넉한 숙소' 5 = '감각있는 숙소'
# 6 = '아름다운 풍경이 가득한 숙소' 7 = '놀기 좋은 숙소' 8 = '편안한 분위기의 숙소' 9 = '하늘과 바다가 가득한 숙소'

# %%
test['category_label'] = np.NaN
for i in test.category:
    if i == 0:
        test['category_label'] = '혼자만의 숙소'
    elif i == 1:
        test['category_label'] = '미정'
    elif i == 2:
        test['category_label'] = '데이트하기 좋은 숙소'        
    elif i == 3:
        test['category_label'] = '특별한 체험이 있는 숙소' 
    elif i == 4:
        test['category_label'] = '고즈넉한 숙소' 
    elif i == 5:
        test['category_label'] = '감각있는 숙소'
    elif i == 6:
        test['category_label'] = '아름다운 풍경이 가득한 숙소'
    elif i == 7:
        test['category_label'] = '놀기 좋은 숙소' 
    elif i == 8:
        test['category_label'] = '편안한 분위기의 숙소' 
    else:
        test['category_label'] = '하늘과 바다가 가득한 숙소'

# %%
test.to_parquet(f'merged_data_{nowtime}')

# %%
test.to_csv('basedata.csv')

# %%
a = spark.read.parquet(f"hdfs://localhost:9000/data/modeldata/merged_data_{nowtime}")

# %%
from pymongo import MongoClient
from datetime import datetime

client = MongoClient('localhost',27017) # mongodb 27017 port
db = client.ojo_db

# %%
for i in a.collect():
    db.cluster.insert_one(i.asDict())

# %%
matrix = create_matrix(test)

for i in range(len(matrix)):
    matrix[i] = list(map(float,matrix[i]))
    
for i in range(len(matrix)):
    db.matrix.insert_one({f'a{i}': matrix[i]})

# %%
for i in range(len(matrix)):
    matrix[i] = list(map(float,matrix[i]))
    
for i in range(len(matrix)):
    db.matrix.insert_one({f'a{i}': matrix[i]})

# %%
# merged_data.to_parquet(f'merged_data_{nowtime}')

# %%
# merged_data.to_csv('merged_data2.csv')

# %%
# 필수 모듈 호출
import pandas as pd
import numpy as np
import re
# Word2Vec embedding
from gensim.models import Word2Vec
from numpy import dot
from numpy.linalg import norm
import numpy as np

# 데이터 로드
from pyspark.conf import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
from pyspark.sql.functions import array_contains, udf

from pymongo import MongoClient
from datetime import datetime

client = MongoClient('localhost',27017) # mongodb 27017 port
db = client.ojo_db

a = spark.read.parquet(f"hdfs://localhost:9000/data/modeldata/merged_data_{nowtime}")
matrix_data = a.toPandas()

def get_sentence_mean_vector(morphs):
    vector = []
    for i in morphs:
        try:
            vector.append(embedding_model.wv[i])
        except KeyError as e:
            pass
    try:
        return sum(vector)/len(vector)
    except IndexError as e:
        pass

def cos_sim(A, B):
       return dot(A, B)/(norm(A)*norm(B))

    
def create_matrix(wv_matrix):
    rows = []
    matrix = []
    for i in range(len(matrix_data.content_x)):
        for x in range(len(matrix_data.content_x)):
            cos_sim = dot(wv_matrix[i], wv_matrix[x])/(norm(wv_matrix[i])*norm(wv_matrix[x]))
            rows.append(cos_sim)
        matrix.append(rows)
        rows=[]
    return matrix


embedding_model = Word2Vec(matrix_data.content_x, vector_size=100, window = 2, min_count=3, workers=4, epochs=100, sg=1, seed=0)
matrix_data['wv'] = matrix_data['content_x'].map(get_sentence_mean_vector)
wv_matrix = np.asarray(matrix_data.wv)
matrix = create_matrix(wv_matrix)

for i in range(len(matrix)):
    matrix[i] = list(map(float,matrix[i]))
    
for i in range(len(matrix)):
    db.matrix.insert_one({f'a{i}': matrix[i]})

# tmp = {}

#     tmp[f'a{i}']= matrix[i]
#     db.matrix.insert_one({f'a{i}': matrix[i]})

# %%
for i in a.collect():
    db.insta.insert_one(i.asDict())
